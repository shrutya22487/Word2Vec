# %%
import torch
import json
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
import task2
# Reuse Word2VecModel and get_triplets from the previous code

if __name__ == "__main__":
    # File paths
    vocab_file_path = "../vocabulary_86.txt"
    model_checkpoint_path = "word2vec_checkpoint.pth"

    # Load vocabulary
    with open(vocab_file_path, "r", encoding="utf-8") as f:
        vocab = [line.strip() for line in f]

    word_to_idx = {word: idx for idx, word in enumerate(vocab)}
    idx_to_word = {idx: word for word, idx in word_to_idx.items()}

    embedding_dim = 50
    context_window = 4

    # Recreate the model
    model = task2.Word2VecModel(len(word_to_idx), embedding_dim)

    # Load saved model weights
    model.load_state_dict(torch.load(model_checkpoint_path))
    model.eval()  # Set to evaluation mode

    # Generate triplets
    triplets = task2.get_triplets(model, word_to_idx, idx_to_word)

    # Print the triplets
    print("Top 20 Triplets:")
    for triplet in triplets[2000:2200]:
        print("Word:", triplet[0])
        print("Similar:", triplet[1])
        print("Dissimilar:", triplet[2])
        print()
# Out:
# C:\Users\shrut\AppData\Local\Temp\ipykernel_19292\2377983432.py:27: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_checkpoint_path))
# Top 20 Triplets:
# Word: ntowa
# Similar: ['##minding', '##uch', 'tug']
# Dissimilar: summed
#
# Word: ntowar
# Similar: ['ours', '##ttainabl', '##yy']
# Dissimilar: doctors
#
# Word: ntoward
# Similar: ['corinthians', '##ition', 'rac']
# Dissimilar: victimiz
#
# Word: fowa
# Similar: ['favouri', 'sanity', 'island']
# Dissimilar: kno
#
# Word: fowar
# Similar: ['education', 'ingr', '##anship']
# Dissimilar: danc
#
# Word: foward
# Similar: ['psycho', 'curi', 'pan']
# Dissimilar: abs
#
# Word: ##ub
# Similar: ['archi', 'billy', 'public']
# Dissimilar: ##sentful
#
# Word: club
# Similar: ['provi', 'powd', '##rsecut']
# Dissimilar: magazine
#
# Word: doub
# Similar: ['consoli', '##auty', 'events']
# Dissimilar: harbor
#
# Word: sub
# Similar: ['##roub', '##iving', 'entirely']
# Dissimilar: flashing
#
# Word: dub
# Similar: ['hobbl', '##rcurr', '##verag']
# Dissimilar: culpr
#
# Word: subm
# Similar: ['##ativity', 'abound', '##kou']
# Dissimilar: corinthians
#
# Word: subp
# Similar: ['marginaliz', 'maintai', 'propo']
# Dissimilar: rejecte
#
# Word: subc
# Similar: ['reach', '##njoy', 'x']
# Dissimilar: ##publi
#
# Word: subco
# Similar: ['arcad', 'drugs', 'wrapping']
# Dissimilar: ##antic
#
# Word: pub
# Similar: ['wait', '##lic', 'marri']
# Dissimilar: dialog
#
# Word: submi
# Similar: ['##nappr', 'volunt', '##siv']
# Dissimilar: will
#
# Word: subcon
# Similar: ['irritat', 'minor', 'corinth']
# Dissimilar: ##is
#
# Word: subcons
# Similar: ['hoho', 'insist', 'grand']
# Dissimilar: uplift
#
# Word: subconsc
# Similar: ['##irtuous', 'stimulat', 'kitch']
# Dissimilar: exhil
#
# Word: subconsci
# Similar: ['horn', 'assistance', 'put']
# Dissimilar: virtuous
#
# Word: subconscio
# Similar: ['particula', 'flash', 'exic']
# Dissimilar: g
#
# Word: subconsciou
# Similar: ['##ollow', 'traffo', '##ak']
# Dissimilar: constr
#
# Word: subconscious
# Similar: ['cze', '##lowing', 'mor']
# Dissimilar: ##pay
#
# Word: ##oub
# Similar: ['sal', 'motivated', 'prin']
# Dissimilar: ##nnual
#
# Word: tub
# Similar: ['##mpting', '##timid', 'disre']
# Dissimilar: choic
#
# Word: ##pub
# Similar: ['formul', '##zilla', '##nking']
# Dissimilar: ##nific
#
# Word: rub
# Similar: ['##rama', 'eyed', 'pal']
# Dissimilar: warming
#
# Word: rubi
# Similar: ['will', 'charact', 'humilia']
# Dissimilar: pink
#
# Word: ##roub
# Similar: ['sub', 'abun', '##ination']
# Dissimilar: giving
#
# Word: troub
# Similar: ['afraid', '##brok', 'loath']
# Dissimilar: pant
#
# Word: ##tub
# Similar: ['##rwin', '##aconic', 'uncon']
# Dissimilar: ##gards
#
# Word: ##ntub
# Similar: ['##mp', '##ischi', '##urous']
# Dissimilar: impul
#
# Word: intub
# Similar: ['chain', 'anyone', '##andmoth']
# Dissimilar: copyright
#
# Word: troubl
# Similar: ['transc', 'much', 'thighs']
# Dissimilar: educat
#
# Word: ##publ
# Similar: ['nut', 'finals', 'mayb']
# Dissimilar: tary
#
# Word: ##publi
# Similar: ['disorgan', 'complicat', 'progra']
# Dissimilar: ##otic
#
# Word: ##public
# Similar: ['obta', '##rwh', '##abb']
# Dissimilar: ##uff
#
# Word: subpa
# Similar: ['cowo', 'childho', 'hospit']
# Dissimilar: brush
#
# Word: subpar
# Similar: ['##odor', 'gif', 'consig']
# Dissimilar: eithe
#
# Word: intuba
# Similar: ['uh', '##italin', 'ganging']
# Dissimilar: ##sinc
#
# Word: intubat
# Similar: ['satisfie', '##rform', '##ephora']
# Dissimilar: ##rytim
#
# Word: subma
# Similar: ['##omach', 'light', 'dream']
# Dissimilar: ##topp
#
# Word: submar
# Similar: ['##nsibl', '##swhyinch', '##phr']
# Dissimilar: ##raffic
#
# Word: submari
# Similar: ['##ion', 'exams', '##aomi']
# Dissimilar: ##crous
#
# Word: submarin
# Similar: ['pragma', 'fin', 'discu']
# Dissimilar: salt
#
# Word: doubt
# Similar: ['di', 'promi', '##ggy']
# Dissimilar: nobo
#
# Word: doubtful
# Similar: ['tickling', 'loos', '##tack']
# Dissimilar: driving
#
# Word: doubl
# Similar: ['notch', '##ptic', 'marijuan']
# Dissimilar: yo
#
# Word: submis
# Similar: ['ev', 'lup', 'cherish']
# Dissimilar: crush
#
# Word: submiss
# Similar: ['proc', 'varsiti', 'summ']
# Dissimilar: ##viously
#
# Word: submissi
# Similar: ['lupron', 'despair', 'moral']
# Dissimilar: ##rtuous
#
# Word: submissiv
# Similar: ['aryiku', 'hallucin', 'along']
# Dissimilar: ##actic
#
# Word: submit
# Similar: ['prettymuch', '##rrrrrrryyyy', 'expensiv']
# Dissimilar: excha
#
# Word: publ
# Similar: ['##autiful', '##rcur', '##gacy']
# Dissimilar: ##rdstroms
#
# Word: publi
# Similar: ['##rsonal', '##mon', 'mutua']
# Dissimilar: ##stalgic
#
# Word: public
# Similar: ['energy', '##xist', '##ts']
# Dissimilar: posts
#
# Word: dubs
# Similar: ['##ic', 'midt', 'signific']
# Dissimilar: ##llowful
#
# Word: dubst
# Similar: ['facult', 'racis', '##rdo']
# Dissimilar: ##asur
#
# Word: dubl
# Similar: ['emily', 'comfortab', 'suffering']
# Dissimilar: vi
#
# Word: dubli
# Similar: ['##nsinc', '##sponsibilit', 'challenging']
# Dissimilar: oppr
#
# Word: dublin
# Similar: ['souls', 'wishing', 'psychopatholog']
# Dissimilar: che
#
# Word: subt
# Similar: ['student', '##ntionally', 'already']
# Dissimilar: loc
#
# Word: subtl
# Similar: ['realize', 'opinio', '##mish']
# Dissimilar: extend
#
# Word: suba
# Similar: ['##moriz', 'amorous', 'similarit']
# Dissimilar: ##taff
#
# Word: subar
# Similar: ['fram', 'midt', '##atman']
# Dissimilar: plain
#
# Word: subaru
# Similar: ['sinus', '##luctant', 'soap']
# Dissimilar: boyfri
#
# Word: subconsciousl
# Similar: ['##lori', 'a', '##uag']
# Dissimilar: wa
#
# Word: subconsciously
# Similar: ['disse', 'pol', 'minorit']
# Dissimilar: ##ma
#
# Word: ##thful
# Similar: ['drugs', 'australians', 'exhal']
# Dissimilar: ##sidu
#
# Word: youthful
# Similar: ['##py', 'christm', 'wildlif']
# Dissimilar: division
#
# Word: ##uthful
# Similar: ['walk', 'puff', '##bord']
# Dissimilar: ##mination
#
# Word: ##ruthful
# Similar: ['##gnific', 'victor', '##ria']
# Dissimilar: changed
#
# Word: truthful
# Similar: ['car', 'someway', '##ntations']
# Dissimilar: boot
#
# Word: shor
# Similar: ['victoria', 'skeptical', '##santly']
# Dissimilar: ##ca
#
# Word: short
# Similar: ['boot', 'nowher', 'everybodys']
# Dissimilar: xang
#
# Word: shov
# Similar: ['##oggy', 'juli', '##nvo']
# Dissimilar: ##alancing
#
# Word: ##ou
# Similar: ['bitch', 'nau', 'anoth']
# Dissimilar: conduct
#
# Word: continuou
# Similar: ['##rif', 'superior', 'despair']
# Dissimilar: ##gious
#
# Word: withou
# Similar: ['dul', '##rforman', 'ugl']
# Dissimilar: pub
#
# Word: continuous
# Similar: ['rapidly', 'ehb', '##antag']
# Dissimilar: ##mpo
#
# Word: wou
# Similar: ['painful', '##ailormoon', 'young']
# Dissimilar: bound
#
# Word: without
# Similar: ['ac', 'waft', 'sadn']
# Dissimilar: skinn
#
# Word: woul
# Similar: ['ruptur', 'historical', 'capa']
# Dissimilar: ##nclu
#
# Word: would
# Similar: ['comp', '##indow', 'ske']
# Dissimilar: friendships
#
# Word: woun
# Similar: ['##knob', 'inspir', '##llions']
# Dissimilar: peak
#
# Word: wound
# Similar: ['hou', 'buni', '##riing']
# Dissimilar: bank
#
# Word: callou
# Similar: ['##artbrok', 'opinions', '##rmor']
# Dissimilar: ##armonious
#
# Word: callous
# Similar: ['exh', 'posting', 'ciga']
# Dissimilar: chih
#
# Word: ##ous
# Similar: ['##nu', 'togethe', '##isocial']
# Dissimilar: calling
#
# Word: throughou
# Similar: ['##iculous', '##kful', 'hims']
# Dissimilar: ba
#
# Word: throughout
# Similar: ['##minist', 'information', 'agree']
# Dissimilar: years
#
# Word: ##oun
# Similar: ['check', 'spreading', 'vow']
# Dissimilar: tx
#
# Word: hou
# Similar: ['typic', 'jimm', 'huge']
# Dissimilar: flaws
#
# Word: ##outh
# Similar: ['##llah', 'cool', 'adole']
# Dissimilar: remains
#
# Word: mouth
# Similar: ['influ', 'monitor', 'outc']
# Dissimilar: starvation
#
# Word: ##ound
# Similar: ['##aniz', 'unimpo', 'notic']
# Dissimilar: eba
#
# Word: ##ounc
# Similar: ['oh', 'kno', '##usiv']
# Dissimilar: ##ku
#
# Word: bounc
# Similar: ['fangi', 'eri', 'impost']
# Dissimilar: ##ahhh
#
# Word: bouncy
# Similar: ['chocolating', 'est', 'hid']
# Dissimilar: platform
#
# Word: ##moun
# Similar: ['anything', '##annual', '##ntis']
# Dissimilar: ##hum
#
# Word: ##coun
# Similar: ['##talin', 'abiliti', 'automati']
# Dissimilar: hating
#
# Word: moun
# Similar: ['sadistic', '##nvincibl', 'pac']
# Dissimilar: celebrates
#
# Word: ##ccoun
# Similar: ['sleeping', '##yb', 'brid']
# Dissimilar: effor
#
# Word: amoun
# Similar: ['occasi', 'cz', 'celebrating']
# Dissimilar: economy
#
# Word: accoun
# Similar: ['loath', '##rsonaliz', 'huma']
# Dissimilar: combi
#
# Word: hour
# Similar: ['ove', '##rifi', '##erat']
# Dissimilar: time
#
# Word: ##nounc
# Similar: ['##atur', 'neglectful', '##wor']
# Dissimilar: contrar
#
# Word: ##ncoun
# Similar: ['word', '##az', 'waits']
# Dissimilar: spirit
#
# Word: encoun
# Similar: ['##akfast', '##asons', 'obj']
# Dissimilar: pupp
#
# Word: mount
# Similar: ['closest', '##thod', '##ntal']
# Dissimilar: els
#
# Word: amount
# Similar: ['prohibit', 'outgoing', '##ankful']
# Dissimilar: comfo
#
# Word: encount
# Similar: ['##grit', 'orthotics', 'unfocu']
# Dissimilar: mayb
#
# Word: account
# Similar: ['prohibitio', '##rmarrying', 'turn']
# Dissimilar: releas
#
# Word: ##onounc
# Similar: ['##rsity', '##manding', '##arful']
# Dissimilar: buni
#
# Word: ##ronounc
# Similar: ['jour', '##utic', '##orribl']
# Dissimilar: hundreds
#
# Word: pronounc
# Similar: ['##ivi', '##izz', '##ry']
# Dissimilar: scor
#
# Word: mounta
# Similar: ['distin', '##andf', 'undercurr']
# Dissimilar: mod
#
# Word: mountai
# Similar: ['accordan', 'honour', 'gu']
# Dissimilar: basicall
#
# Word: mountain
# Similar: ['##uth', 'butt', '##formation']
# Dissimilar: emot
#
# Word: ##kou
# Similar: ['bands', 'subm', 'victi']
# Dissimilar: ##ub
#
# Word: ##rkou
# Similar: ['painful', 'od', 'fanta']
# Dissimilar: tackl
#
# Word: ##orkou
# Similar: ['##kin', 'helple', '##ltimat']
# Dissimilar: sexual
#
# Word: workou
# Similar: ['block', 'tumm', 'genuflecting']
# Dissimilar: cor
#
# Word: workout
# Similar: ['scor', '##ecaus', '##ekends']
# Dissimilar: face
#
# Word: ##round
# Similar: ['holding', 'harras', 'don']
# Dissimilar: skeleton
#
# Word: ground
# Similar: ['##nyon', 'frizz', '##vin']
# Dissimilar: sign
#
# Word: around
# Similar: ['admi', 'puts', 'eyed']
# Dissimilar: ##sty
#
# Word: ##ground
# Similar: ['lam', '##ativ', 'outg']
# Dissimilar: although
#
# Word: background
# Similar: ['gone', 'encourag', 'snippy']
# Dissimilar: ##sty
#
# Word: ##bound
# Similar: ['snail', '##odor', '##na']
# Dissimilar: austra
#
# Word: found
# Similar: ['evaluating', 'abund', 'nation']
# Dissimilar: ##ertain
#
# Word: round
# Similar: ['harbor', '##nyon', '##aki']
# Dissimilar: significan
#
# Word: pound
# Similar: ['unfortu', '##ginia', '##rmally']
# Dissimilar: adams
#
# Word: bound
# Similar: ['gosman', 'todo', 'hardly']
# Dissimilar: easy
#
# Word: pounding
# Similar: ['yet', 'nu', '##rcolat']
# Dissimilar: zooming
#
# Word: ##rround
# Similar: ['##tman', 'jou', 'mccarthy']
# Dissimilar: subjects
#
# Word: ##urround
# Similar: ['painful', '##ard', 'smiling']
# Dissimilar: attachment
#
# Word: surround
# Similar: ['yourself', 'effo', '##arin']
# Dissimilar: ##ntia
#
# Word: bounda
# Similar: ['##itish', '##loa', '##eliev']
# Dissimilar: bondmu
#
# Word: boundar
# Similar: ['##nabl', 'minuscul', 'honest']
# Dissimilar: twic
#
# Word: boundari
# Similar: ['floating', '##ptions', 'teenage']
# Dissimilar: combi
#
# Word: hours
# Similar: ['bag', 'x', 'dharm']
# Dissimilar: ##llingham
#
# Word: ##bou
# Similar: ['##nal', 'into', '##curit']
# Dissimilar: sting
#
# Word: ##bour
# Similar: ['##bly', 'suitca', 'damag']
# Dissimilar: unloved
#
# Word: ##abour
# Similar: ['criticize', 'bun', 'unlove']
# Dissimilar: drop
#
# Word: labour
# Similar: ['##articu', 'swift', '##shion']
# Dissimilar: diss
#
# Word: ##vous
# Similar: ['lords', 'mut', 'bit']
# Dissimilar: ##tact
#
# Word: ##rvous
# Similar: ['alarm', 'team', 'promotion']
# Dissimilar: employ
#
# Word: ##ious
# Similar: ['mart', 'sharing', 'enquiri']
# Dissimilar: focu
#
# Word: ##xious
# Similar: ['##mplat', 'gir', 'trust']
# Dissimilar: ris
#
# Word: ##cious
# Similar: ['##nonym', 'unfol', 'adole']
# Dissimilar: snoot
#
# Word: conscious
# Similar: ['foca', 'shak', 'exampl']
# Dissimilar: ##ippy
#
# Word: ##vious
# Similar: ['gifts', 'cinnam', '##rgu']
# Dissimilar: ##col
#
# Word: ##gious
# Similar: ['nois', '##ua', '##coffing']
# Dissimilar: continuou
#
# Word: ##igious
# Similar: ['machin', 'habitual', '##inally']
# Dissimilar: unpr
#
# Word: ##ligious
# Similar: ['allow', '##loci', '##i']
# Dissimilar: agita
#
# Word: ##agious
# Similar: ['on', '##rantic', 'politicia']
# Dissimilar: ##ind
#
# Word: contagious
# Similar: ['socks', '##gnancy', 'buzzy']
# Dissimilar: ##latitud
#
# Word: ##nxious
# Similar: ['flick', 'tak', 'lingering']
# Dissimilar: rod
#
# Word: ##oxious
# Similar: ['##lf', 'occu', '##luffy']
# Dissimilar: mood
#
# Word: anxious
# Similar: ['cris', 'gatsby', 'outca']
# Dissimilar: ea
#
# Word: ##noxious
# Similar: ['various', '##turn', '##finition']
# Dissimilar: ##nhuma
#
# Word: obnoxious
# Similar: ['##nshi', 'ways', '##finit']
# Dissimilar: asha
#
# Word: spous
# Similar: ['##talgic', 'arrog', '##eavenly']
# Dissimilar: fuch
#
# Word: hous
# Similar: ['##nteracting', '##asur', '##vori']
# Dissimilar: weepy
#
# Word: ##nvious
# Similar: ['##vic', 'hosp', 'discov']
# Dissimilar: ##llions
#
# Word: envious
# Similar: ['##rforming', 'es', 'disillu']
# Dissimilar: girlfri
#
# Word: ##icious
# Similar: ['##lancholy', 'happin', 'lips']
# Dissimilar: shinae
#
# Word: vicious
# Similar: ['purcha', 'tow', 'notice']
# Dissimilar: convolut
#
# Word: ##picious
# Similar: ['##mitat', '##bra', 'actions']
# Dissimilar: ##wha
#
# Word: ##spicious
# Similar: ['but', 'models', '##dship']
# Dissimilar: ##eliev
#
# Word: ##uspicious
# Similar: ['annoying', 'colou', 'thai']
# Dissimilar: party
#
# Word: suspicious
# Similar: ['inquir', '##ruth', 'communicati']
# Dissimilar: ##spond
#
# Word: ##licious
# Similar: ['promising', 'limit', '##fuddl']
# Dissimilar: innoc
#
# Word: ##vou
# Similar: ['action', 'grabb', 'phon']
# Dissimilar: slu
#
# Word: ##vour
# Similar: ['##raff', 'exams', '##rficia']
# Dissimilar: ##ohibi
#
# Word: ##avour
# Similar: ['##minds', 'describe', 'uncha']
# Dissimilar: walmar
#
# Word: favour
# Similar: ['choc', 'whiney', '##im']
# Dissimilar: ##alling
#
# Word: favouri
# Similar: ['fowa', 'faking', '##wha']
# Dissimilar: shadows
#
# Word: favours
# Similar: ['##aith', '##nstruction', 'anguish']
# Dissimilar: ##por
#
# Word: favourit
# Similar: ['spontan', 'absol', '##obl']
# Dissimilar: alarming
#
# Word: mountains
# Similar: ['privi', '##ducation', 'tryi']
# Dissimilar: acad
#
# Word: pounds
# Similar: ['providing', 'lov', '##tation']
# Dissimilar: ##nstinct
#
# Word: ##rious
# Similar: ['dv', '##produc', 'ready']
# Dissimilar: ##indow
#
# Word: ##lious
# Similar: ['way', '##lebrating', 'dignit']
# Dissimilar: ##gg
#
# Word: ##nious
# Similar: ['significant', 'thir', 'childhoo']
# Dissimilar: popula
#
# Word: ##llious
# Similar: ['fil', 'prim', '##c']
# Dissimilar: closu
#
# Word: ##onious
# Similar: ['##adio', 'birding', 'jongwoo']
# Dissimilar: ##njustic
#
# Word: ##monious
# Similar: ['frankl', 'embra', 'cre']
# Dissimilar: ##lui
#
# Word: ##rmonious
# Similar: ['obv', 'honk', '##vi']
# Dissimilar: truly
#
# Word: ##armonious
# Similar: ['##oking', 'ev', 'jok']
# Dissimilar: callou
#
# Word: harmonious
# Similar: ['##otypical', '##our', 'minis']
# Dissimilar: nakahar
#
# Word: ##uish
# Similar: ['superman', '##ropp', '##y']
# Dissimilar: ##ca
#
# Word: anguish
# Similar: ['##dici', '##rank', 'favours']
# Dissimilar: ##sland
#
# Word: ##our
# Similar: ['##cia', '##a', 'harmonious']
# Dissimilar: traumatis
#
# Word: ##ourous
# Similar: ['##raff', 'spok', '##ook']
# Dissimilar: rach
#
# Word: ##mourous
# Similar: ['##rmalcy', 'inside', 'vibrant']
# Dissimilar: ##back
#
# Word: ##amourous
# Similar: ['##suriz', 'inquir', 'cockt']
# Dissimilar: ##actic
#
# Word: ##lamourous
# Similar: ['engin', 'conservativ', '##lfway']
# Dissimilar: ##egl
