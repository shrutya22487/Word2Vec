# %%
import torch
import json
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
import task2
# Reuse Word2VecModel and get_triplets from the previous code

if __name__ == "__main__":
    # File paths
    vocab_file_path = "../vocabulary_86.txt"
    model_checkpoint_path = "word2vec_checkpoint.pth"

    # Load vocabulary
    with open(vocab_file_path, "r", encoding="utf-8") as f:
        vocab = [line.strip() for line in f]

    word_to_idx = {word: idx for idx, word in enumerate(vocab)}
    idx_to_word = {idx: word for word, idx in word_to_idx.items()}

    embedding_dim = 30
    context_window = 3

    # Recreate the model
    model = task2.Word2VecModel(len(word_to_idx), embedding_dim)

    # Load saved model weights
    model.load_state_dict(torch.load(model_checkpoint_path))
    model.eval()  # Set to evaluation mode

    # Generate triplets
    triplets = task2.get_triplets(model, word_to_idx, idx_to_word)

    # Print the triplets
    print("Top 20 Triplets:")
    for triplet in triplets[600:700]:
        print("Word:", triplet[0])
        print("Similar:", triplet[1])
        print("Dissimilar:", triplet[2])
        print()
# Out:
# C:\Users\shrut\AppData\Local\Temp\ipykernel_19292\3879099152.py:27: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_checkpoint_path))
# Top 20 Triplets:
# Word: pho
# Similar: ['possibili', 'anim', 'apocaly']
# Dissimilar: ##yvor
#
# Word: phi
# Similar: ['mount', '##topp', 'abi']
# Dissimilar: outburst
#
# Word: phr
# Similar: ['mountain', 'lettuc', 'favour']
# Dissimilar: ##ecr
#
# Word: phil
# Similar: ['stimulating', 'saturda', '##sibil']
# Dissimilar: ##istan
#
# Word: philo
# Similar: ['aoi', 'cynicis', 'disor']
# Dissimilar: row
#
# Word: philos
# Similar: ['##reading', '##otyp', 'environm']
# Dissimilar: lapping
#
# Word: philoso
# Similar: ['clar', 'afa', 'tr']
# Dissimilar: quil
#
# Word: philosop
# Similar: ['exhaling', 'hil', 'mildly']
# Dissimilar: exhibitions
#
# Word: philosoph
# Similar: ['fuch', 'bonu', 'w']
# Dissimilar: ##ndship
#
# Word: philosophy
# Similar: ['##llo', 'funny', '##ronounc']
# Dissimilar: unimport
#
# Word: phra
# Similar: ['hiv', 'remorseful', 'subconsciousl']
# Dissimilar: ##sponsibili
#
# Word: phras
# Similar: ['ear', 'nef', 'overwork']
# Dissimilar: comatos
#
# Word: ##sh
# Similar: ['##riticiz', 'ungr', 'courag']
# Dissimilar: cyst
#
# Word: unh
# Similar: ['##lyvor', '##hind', '##gic']
# Dissimilar: pleasur
#
# Word: nowh
# Similar: ['psychopatholo', '##venty', '##ntury']
# Dissimilar: ##sha
#
# Word: ##hh
# Similar: ['resentful', '##yvor', 'thoughtful']
# Dissimilar: ##somnia
#
# Word: ##hhh
# Similar: ['digital', 'tru', 'baptiz']
# Dissimilar: yelling
#
# Word: kh
# Similar: ['greg', 'wish', 'stun']
# Dissimilar: jail
#
# Word: kha
# Similar: ['oka', 'not', 'mount']
# Dissimilar: what
#
# Word: khal
# Similar: ['cantank', 'infr', 'organiz']
# Dissimilar: khalif
#
# Word: khali
# Similar: ['pul', 'doctor', 'slutt']
# Dissimilar: signific
#
# Word: khalif
# Similar: ['chab', 'subt', 'filt']
# Dissimilar: equall
#
# Word: khalifa
# Similar: ['ideas', 'emotionally', '##nough']
# Dissimilar: choices
#
# Word: ##ahhh
# Similar: ['clench', 'estee', 'gif']
# Dissimilar: eg
#
# Word: aahhh
# Similar: ['chur', 'prove', '##atory']
# Dissimilar: chiangma
#
# Word: ##mph
# Similar: ['cry', 'complication', '##divid']
# Dissimilar: ##stalgic
#
# Word: ##umph
# Similar: ['canada', 'dissol', 'unfit']
# Dissimilar: smooth
#
# Word: ##iumph
# Similar: ['##door', 'hoard', 'unwil']
# Dissimilar: terrifie
#
# Word: ##riumph
# Similar: ['ultimat', 'whilst', 'post']
# Dissimilar: stores
#
# Word: triumph
# Similar: ['##icat', 'desp', 'green']
# Dissimilar: creed
#
# Word: triumpha
# Similar: ['##velop', '##curi', '##kou']
# Dissimilar: everywh
#
# Word: triumphan
# Similar: ['comfo', '##pp', '##trian']
# Dissimilar: ##elebrating
#
# Word: triumphant
# Similar: ['##vori', '##phora', '##sking']
# Dissimilar: tomfool
#
# Word: ##ph
# Similar: ['yes', 'ugly', '##oop']
# Dissimilar: esteem
#
# Word: oh
# Similar: ['zambi', 'trials', '##ww']
# Dissimilar: ##ju
#
# Word: oth
# Similar: ['##cal', '##nsory', 'sin']
# Dissimilar: thursd
#
# Word: ##thing
# Similar: ['atop', '##ritional', '##rgiving']
# Dissimilar: bonk
#
# Word: ##ything
# Similar: ['leaning', 'artists', 'naughty']
# Dissimilar: grass
#
# Word: ##ith
# Similar: ['press', 'unlove', 'clothing']
# Dissimilar: ##iwon
#
# Word: with
# Similar: ['mos', 'exci', '##ncid']
# Dissimilar: ##ft
#
# Word: eith
# Similar: ['loos', '##pidation', '##nds']
# Dissimilar: main
#
# Word: ##ithf
# Similar: ['excit', 'easygo', '##nsation']
# Dissimilar: appropria
#
# Word: ##ithfu
# Similar: ['##lationship', '##vantag', '##iably']
# Dissimilar: sincerity
#
# Word: ##thiz
# Similar: ['approach', 'chain', '##clut']
# Dissimilar: ##diculous
#
# Word: ##thizing
# Similar: ['cycl', 'worried', '##ersonifying']
# Dissimilar: ##ruc
#
# Word: ##ithful
# Similar: ['flatt', 'disor', 'maste']
# Dissimilar: obligatio
#
# Word: ##aithful
# Similar: ['##rownish', 'stun', 'erm']
# Dissimilar: ##garding
#
# Word: faithful
# Similar: ['##dish', 'fulfillm', 'in']
# Dissimilar: ##aming
#
# Word: ##athiz
# Similar: ['##maidhai', 'realiz', 'zon']
# Dissimilar: prick
#
# Word: empathiz
# Similar: ['##aryb', 'typ', '##atur']
# Dissimilar: lying
#
# Word: ##athizing
# Similar: ['battl', '##mpathizing', '##clut']
# Dissimilar: brav
#
# Word: ##mpathizing
# Similar: ['at', '##athizing', 'coop']
# Dissimilar: snow
#
# Word: ##ympathizing
# Similar: ['##ct', 'pills', 'sponta']
# Dissimilar: polar
#
# Word: sympathizing
# Similar: ['attention', '##latonic', '##cut']
# Dissimilar: ##akishly
#
# Word: ##mith
# Similar: ['clench', 'wak', '##qui']
# Dissimilar: ##odorant
#
# Word: smith
# Similar: ['hre', 'cantank', '##elf']
# Dissimilar: tire
#
# Word: smiths
# Similar: ['##onious', 'grandios', 'particula']
# Dissimilar: ortho
#
# Word: ##thqu
# Similar: ['##work', 'uncomfortab', 'consol']
# Dissimilar: tri
#
# Word: ##rthqu
# Similar: ['possibility', '##nicky', 'nowh']
# Dissimilar: ##ulanc
#
# Word: ##arthqu
# Similar: ['occasiona', 'mor', 'continually']
# Dissimilar: expensiv
#
# Word: earthqu
# Similar: ['##ef', 'jaws', '##iterat']
# Dissimilar: pulp
#
# Word: earthqua
# Similar: ['##you', '##takingly', 'negl']
# Dissimilar: curiosit
#
# Word: earthquak
# Similar: ['##inding', 'obviousl', 'bound']
# Dissimilar: walk
#
# Word: ##ish
# Similar: ['twas', 'transc', 'privil']
# Dissimilar: dissati
#
# Word: squish
# Similar: ['##ring', 'crushing', 'huge']
# Dissimilar: antic
#
# Word: squishing
# Similar: ['wha', 'unfor', 'had']
# Dissimilar: mircowav
#
# Word: ##fish
# Similar: ['class', 'enthusi', 'vibratio']
# Dissimilar: ##plac
#
# Word: wish
# Similar: ['creed', '##havi', 'factor']
# Dissimilar: ##locat
#
# Word: ##ckish
# Similar: ['critic', 'gho', '##riously']
# Dissimilar: examin
#
# Word: ##lfish
# Similar: ['smok', 'disill', 'amorous']
# Dissimilar: knelt
#
# Word: ##bish
# Similar: ['took', '##rribly', 'organizational']
# Dissimilar: florida
#
# Word: ##bbish
# Similar: ['##upi', 'qui', '##itabl']
# Dissimilar: balloons
#
# Word: ##obbish
# Similar: ['##nsomnia', 'cream', 'inste']
# Dissimilar: ##magination
#
# Word: ##nobbish
# Similar: ['energ', 'introduced', '##culous']
# Dissimilar: ##eks
#
# Word: snobbish
# Similar: ['vomiting', 'constructivis', 'chu']
# Dissimilar: turnov
#
# Word: dish
# Similar: ['graying', 'proj', 'kitch']
# Dissimilar: resigne
#
# Word: ##ush
# Similar: ['coul', 'adop', 'suppos']
# Dissimilar: finds
#
# Word: rush
# Similar: ['dunno', '##rthwhi', '##mouring']
# Dissimilar: ##urround
#
# Word: push
# Similar: ['from', '##acting', 'awh']
# Dissimilar: radia
#
# Word: gush
# Similar: ['back', 'haus', '##swhyin']
# Dissimilar: consistently
#
# Word: ##rush
# Similar: ['##clusiv', '##rcurr', '##gniz']
# Dissimilar: ##vas
#
# Word: brush
# Similar: ['fami', '##ophi', 'examinatio']
# Dissimilar: ##artbrok
#
# Word: crush
# Similar: ['suicid', '##unding', 'lung']
# Dissimilar: pott
#
# Word: crushing
# Similar: ['drak', '##oying', 'struggle']
# Dissimilar: ##latonic
#
# Word: ##lush
# Similar: ['grav', 'right', '##dag']
# Dissimilar: focu
#
# Word: blush
# Similar: ['asid', 'christ', 'err']
# Dissimilar: kor
#
# Word: flush
# Similar: ['##bl', 'as', '##ari']
# Dissimilar: ##ain
#
# Word: ##shi
# Similar: ['##rrita', 'communal', 'discomfort']
# Dissimilar: ##ourous
#
# Word: ##ship
# Similar: ['squi', '##ato', 'islam']
# Dissimilar: laid
#
# Word: ##nship
# Similar: ['enthusiastic', 'extremly', 'disorg']
# Dissimilar: disillusione
#
# Word: ##onship
# Similar: ['extend', '##bly', 'cupcak']
# Dissimilar: and
#
# Word: ##ionship
# Similar: ['##tatch', '##ulatory', 'spont']
# Dissimilar: disappr
#
# Word: ##tionship
# Similar: ['##assiona', '##nitial', '##ritabl']
# Dissimilar: journa
#
# Word: ##ationship
# Similar: ['chore', '##lfar', '##im']
# Dissimilar: ##actic
#
# Word: ##lationship
# Similar: ['class', '##ithfu', 'submarin']
# Dissimilar: upsid
#
# Word: ##anship
# Similar: ['un', 'platform', 'extra']
# Dissimilar: preschool
#
# Word: ##ianship
# Similar: ['##tump', 'press', '##egl']
# Dissimilar: discussing
#
# Word: ##cianship
# Similar: ['atmosph', 'summe', 'hav']
# Dissimilar: rolls
#
# Word: ##icianship
# Similar: ['hobica', 'his', '##gnant']
# Dissimilar: ##foo
#
# Word: ##sicianship
# Similar: ['submi', '##inctiv', '##rimming']
# Dissimilar: ##ama
