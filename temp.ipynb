# %%
import torch
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
import json

# Load mappings
def load_mappings():
    vocab_file_path = "vocabulary_86.txt"

    with open(vocab_file_path, "r", encoding="utf-8") as f:
        vocab = [line.strip() for line in f]

    word_index_mapping = {word: i for i, word in enumerate(vocab)}
    index_word_mapping = {i: word for word, i in word_index_mapping.items()}

    return word_index_mapping, index_word_mapping

# Load model class
class Word2VecModel(torch.nn.Module):
    def __init__(self, vocab_size, embedding_dim, dropout_rate):
        super().__init__()
        self.network = torch.nn.Sequential(
            torch.nn.Embedding(vocab_size, embedding_dim),
            torch.nn.Dropout(dropout_rate),
            torch.nn.Linear(embedding_dim, vocab_size)
        )

    def forward(self, context):
        embedded = self.network[0](context).mean(dim=1)
        aggregated = self.network[1](embedded)
        out = self.network[2](aggregated)
        return out
    def get_triplets(self):

        """"
        Will generate 5 random triplets and show the similarities as well
        remember to reound them off
        """
        embeddings = self.network[0].weight.data.cpu().numpy()

        #Reference -> https://scikit-learn.org/stable/modules/generated/sklearn.metrics.pairwise.cosine_similarity.html
        cos_similarity_mat = cosine_similarity(embeddings)
        indexes = []
        triplets = []
        for word, index in word_index_mapping.items():
            similar, similar_indices_list = [], []

            similar_indices = np.argsort(cos_similarity_mat[index])[::-1]

            for i in similar_indices:
                if i != index:
                    similar_indices_list.append(i)

            similar_indices = similar_indices_list[:3]

            for i in similar_indices:
                similar.append([index_word_mapping[i], cos_similarity_mat[index][i]])

            dissimilar_index = np.argsort(cos_similarity_mat[index])[0]
            dissimilar = (index_word_mapping[dissimilar_index], cos_similarity_mat[index][dissimilar_index])

            triplet = [word, similar, dissimilar]
            triplets.append(triplet)

        for triplet in triplets:
            print(triplet[0], "\n")
            print("similar words:")
            for i in range(len(triplet[1])):
                print("word: " ,triplet[1][i][0]," ", "with similarity: ", triplet[1][i][1])
            print("Dissimilar:", triplet[2][0], triplet[2][1] , "\n")


# Load model from .pth file
def load_model(filepath, vocab_size, embedding_dim, dropout_rate):
    model = Word2VecModel(vocab_size, embedding_dim, dropout_rate)
    model.load_state_dict(torch.load(filepath))
    model.eval()
    return model

# Generate triplets for a word
def get_triplet_for_word(model, word, word_index_mapping, index_word_mapping):
    if word not in word_index_mapping:
        print(f"{word} not found in vocabulary")
        return

    index_of_word = word_index_mapping[word]
    embeddings = model.network[0].weight.data.cpu().numpy()
    cos_similarity_mat = cosine_similarity(embeddings)

    similar_indices = np.argsort(cos_similarity_mat[index_of_word])[::-1]
    similar = [[index_word_mapping[i], cos_similarity_mat[index_of_word][i]]
               for i in similar_indices if i != index_of_word][:3]

    dissimilar_index = np.argsort(cos_similarity_mat[index_of_word])[0]
    dissimilar = [index_word_mapping[dissimilar_index], cos_similarity_mat[index_of_word][dissimilar_index]]

    print(f"{word}\nSimilar words:")
    for sim in similar:
        print(f"{sim[0]} with similarity {sim[1]:.4f}")
    print(f"Dissimilar: {dissimilar[0]} with similarity {dissimilar[1]:.4f}\n")

if __name__ == "__main__":
    vocab_size = 14000
    embedding_dim = 600
    dropout_rate = 0.3
    model_path = "word2vec_checkpoint.pth"

    word_index_mapping, index_word_mapping = load_mappings()
    model = load_model(model_path, vocab_size, embedding_dim, dropout_rate)

    model.get_triplets()
# Out:
# C:\Users\shrut\AppData\Local\Temp\ipykernel_12904\3052797527.py:76: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(filepath))
# [PAD]
#
# similar words:
# word:  earning   with similarity:  0.7073668
# word:  thinner   with similarity:  0.65173614
# word:  pure   with similarity:  0.6193519
# Dissimilar: walmart -0.43760082
#
# [UNK]
#
# similar words:
# word:  unstable   with similarity:  0.15642601
# word:  midt   with similarity:  0.14526747
# word:  ji   with similarity:  0.14168407
# Dissimilar: ##mporari -0.17963327
#
# ##a
#
# similar words:
# word:  jump   with similarity:  0.7806083
# word:  kill   with similarity:  0.7777572
# word:  talent   with similarity:  0.746179
# Dissimilar: east -0.5089629
#
# ##b
#
# similar words:
# word:  walma   with similarity:  0.14685746
# word:  env   with similarity:  0.14439406
# word:  mir   with similarity:  0.14374566
# Dissimilar: challe -0.15020862
#
# ##c
#
# similar words:
# word:  ##frig   with similarity:  0.14521769
# word:  woul   with similarity:  0.1388793
# word:  ##rch   with similarity:  0.13325688
# Dissimilar: ##tubborn -0.15085664
#
# ##d
#
# similar words:
# word:  headphones   with similarity:  0.61998135
# word:  argument   with similarity:  0.5954819
# word:  austen   with similarity:  0.5945545
# Dissimilar: verrrrrrrryyyy -0.4054312
#
# ##e
#
# similar words:
# word:  initiation   with similarity:  0.7259513
# word:  assistant   with similarity:  0.6882644
# word:  grade   with similarity:  0.6686033
# Dissimilar: exhibit -0.36068982
#
# ##f
#
# similar words:
# word:  ##employm   with similarity:  0.16903141
# word:  ##bsit   with similarity:  0.15082003
# word:  planne   with similarity:  0.14478648
# Dissimilar: ##app -0.16615728
#
# ##g
#
# similar words:
# word:  s   with similarity:  0.58899873
# word:  chiangmai   with similarity:  0.4857886
# word:  upon   with similarity:  0.42955405
# Dissimilar: wh -0.30660906
#
# ##h
#
# similar words:
# word:  officer   with similarity:  0.7890127
# word:  snaps   with similarity:  0.6677762
# word:  handled   with similarity:  0.65054023
# Dissimilar: nobody -0.33281982
#
# ##i
#
# similar words:
# word:  ##cabb   with similarity:  0.15756288
# word:  ##earn   with similarity:  0.13912511
# word:  misunde   with similarity:  0.13731907
# Dissimilar: fatti -0.14956576
#
# ##j
#
# similar words:
# word:  ##ntia   with similarity:  0.16033018
# word:  subconsci   with similarity:  0.14278859
# word:  ##bow   with similarity:  0.14007878
# Dissimilar: unsolve -0.15732682
#
# ##k
#
# similar words:
# word:  orthot   with similarity:  0.15322782
# word:  el   with similarity:  0.15289918
# word:  espous   with similarity:  0.1420874
# Dissimilar: ##elessly -0.14568341
#
# ##l
#
# similar words:
# word:  ##a   with similarity:  0.6900795
# word:  apathetic   with similarity:  0.62846005
# word:  bears   with similarity:  0.5948545
# Dissimilar: reilly -0.44675243
#
# ##m
#
# similar words:
# word:  ##alking   with similarity:  0.1597613
# word:  establish   with similarity:  0.14995348
# word:  ##aking   with similarity:  0.13106775
# Dissimilar: plung -0.14550327
#
# ##n
#
# similar words:
# word:  cut   with similarity:  0.59751964
# word:  spoilers   with similarity:  0.5593699
# word:  exempted   with similarity:  0.5498016
# Dissimilar: wh -0.41712886
#
# ##o
#
# similar words:
# word:  chr   with similarity:  0.14456095
# word:  appal   with similarity:  0.13183305
# word:  enti   with similarity:  0.1290343
# Dissimilar: indicate -0.15955015
#
# ##p
#
# similar words:
# word:  ##ealn   with similarity:  0.14332616
# word:  ebay   with similarity:  0.14045033
# word:  ##ns   with similarity:  0.13715701
# Dissimilar: logic -0.15872058
#
# ##q
#
# similar words:
# word:  pi   with similarity:  0.15637885
# word:  warfight   with similarity:  0.14281818
# word:  ##cit   with similarity:  0.1422423
# Dissimilar: ambulanc -0.15382472
#
# ##r
#
# similar words:
# word:  carrry   with similarity:  0.67091995
# word:  mixed   with similarity:  0.6453177
# word:  sent   with similarity:  0.6316341
# Dissimilar: east -0.40721208
#
# ##s
#
# similar words:
# word:  enacting   with similarity:  0.56588227
# word:  mermaidhaire   with similarity:  0.54276526
# word:  benefit   with similarity:  0.5150527
# Dissimilar: verrrrrrrryyyy -0.3501075
#
# ##t
#
# similar words:
# word:  ##at   with similarity:  0.62652504
# word:  austen   with similarity:  0.5919152
# word:  ##an   with similarity:  0.5796362
# Dissimilar: verrrrrrrryyyy -0.3812546
#
# ##u
#
# similar words:
# word:  cohen   with similarity:  0.14596258
# word:  exch   with similarity:  0.13850412
# word:  iphon   with similarity:  0.13480245
# Dissimilar: observant -0.17377684
#
# ##v
#
# similar words:
# word:  bagg   with similarity:  0.17921638
# word:  khali   with similarity:  0.14028952
# word:  ##rthqu   with similarity:  0.13700432
# Dissimilar: colo -0.14618564
#
# ##w
#
# similar words:
# word:  roman   with similarity:  0.15095402
# word:  pretty   with similarity:  0.13780358
# word:  packag   with similarity:  0.13732073
# Dissimilar: wand -0.1303843
#
# ##x
#
# similar words:
# word:  terribl   with similarity:  0.18260317
# word:  conf   with similarity:  0.17190838
# word:  noi   with similarity:  0.15136862
# Dissimilar: degree -0.17573878
#
# ##y
#
# similar words:
# word:  ##abb   with similarity:  0.15006876
# word:  impo   with similarity:  0.13952532
# word:  fai   with similarity:  0.13819396
# Dissimilar: ##ari -0.15649989
#
# ##z
#
# similar words:
# word:  vitamins   with similarity:  0.17469177
# word:  absolu   with similarity:  0.15706955
# word:  machiav   with similarity:  0.15258959
# Dissimilar: emi -0.15345429
#
# a
#
# similar words:
# word:  mooshilu   with similarity:  0.572201
# word:  shove   with similarity:  0.5411241
# word:  success   with similarity:  0.5265957
# Dissimilar: verse -0.3181287
#
# b
#
# similar words:
# word:  took   with similarity:  0.5395408
# word:  cartwheel   with similarity:  0.5326632
# word:  held   with similarity:  0.49064016
# Dissimilar: appropriately -0.40816438
#
# c
#
# similar words:
# word:  planner   with similarity:  0.6469334
# word:  secretary   with similarity:  0.58697987
# word:  mixed   with similarity:  0.5856849
# Dissimilar: cobwebs -0.3624735
#
# d
#
# similar words:
# word:  gas   with similarity:  0.49149674
# word:  coeur   with similarity:  0.46208596
# word:  scream   with similarity:  0.42740548
# Dissimilar: clinique -0.30510414
#
# e
#
# similar words:
# word:  owl   with similarity:  0.6645324
# word:  instant   with similarity:  0.5332523
# word:  ativan   with similarity:  0.51362944
# Dissimilar: inherent -0.3087839
#
# f
#
# similar words:
# word:  planned   with similarity:  0.7468693
# word:  habitual   with similarity:  0.71996754
# word:  won   with similarity:  0.61727923
# Dissimilar: seventy -0.37951475
#
# g
#
# similar words:
# word:  came   with similarity:  0.15562402
# word:  cz   with similarity:  0.14971593
# word:  says   with similarity:  0.14391406
# Dissimilar: pakis -0.13861269
#
# h
#
# similar words:
# word:  ##nclud   with similarity:  0.16265732
# word:  humbl   with similarity:  0.14297636
# word:  disposa   with similarity:  0.14159867
# Dissimilar: ballis -0.14461042
#
# i
#
# similar words:
# word:  heavy   with similarity:  0.6751559
# word:  ryder   with similarity:  0.67126393
# word:  defined   with similarity:  0.6365334
# Dissimilar: beside -0.5095218
#
# j
#
# similar words:
# word:  lead   with similarity:  0.51945275
# word:  figt   with similarity:  0.51118714
# word:  impoverished   with similarity:  0.50550133
# Dissimilar: antisocial -0.32809925
#
# k
#
# similar words:
# word:  ##agull   with similarity:  0.15106304
# word:  loga   with similarity:  0.14993712
# word:  sentime   with similarity:  0.14156437
# Dissimilar: ##ensiv -0.16286632
#
# l
#
# similar words:
# word:  allie   with similarity:  0.158472
# word:  arouse   with similarity:  0.15248619
# word:  ris   with similarity:  0.15196717
# Dissimilar: batt -0.17307566
#
# m
#
# similar words:
# word:  peep   with similarity:  0.6846263
# word:  austen   with similarity:  0.64832413
# word:  hairstyle   with similarity:  0.6454892
# Dissimilar: wh -0.48268253
#
# n
#
# similar words:
# word:  lyman   with similarity:  0.76094747
# word:  austen   with similarity:  0.7181694
# word:  ow   with similarity:  0.713688
# Dissimilar: hath -0.45344245
#
# o
#
# similar words:
# word:  skinner   with similarity:  0.44667703
# word:  psych   with similarity:  0.3745988
# word:  permanent   with similarity:  0.34163338
# Dissimilar: sacrifice -0.40470532
#
# p
#
# similar words:
# word:  list   with similarity:  0.7512991
# word:  beat   with similarity:  0.7000397
# word:  austen   with similarity:  0.69994974
# Dissimilar: wh -0.59050715
#
# q
#
# similar words:
# word:  belly   with similarity:  0.60596955
# word:  forth   with similarity:  0.6012906
# word:  tries   with similarity:  0.58989996
# Dissimilar: east -0.38133258
#
# r
#
# similar words:
# word:  austen   with similarity:  0.65632135
# word:  hat   with similarity:  0.634555
# word:  ##ar   with similarity:  0.62861806
# Dissimilar: verrrrrrrryyyy -0.4095629
#
# s
#
# similar words:
# word:  hairstyle   with similarity:  0.6329653
# word:  forced   with similarity:  0.6037078
# word:  jimmys   with similarity:  0.59703285
# Dissimilar: wh -0.5575272
#
# t
#
# similar words:
# word:  problemn   with similarity:  0.54071504
# word:  paraphrase   with similarity:  0.49402705
# word:  bio   with similarity:  0.4916854
# Dissimilar: cobwebs -0.2675305
#
# u
#
# similar words:
# word:  admired   with similarity:  0.6166651
# word:  interesting   with similarity:  0.5953902
# word:  ryder   with similarity:  0.5939144
# Dissimilar: onto -0.3854037
#
# v
#
# similar words:
# word:  divin   with similarity:  0.15788487
# word:  disapp   with similarity:  0.14852181
# word:  fucki   with similarity:  0.14806479
# Dissimilar: ##tant -0.15279339
#
# w
#
# similar words:
# word:  volunt   with similarity:  0.1486793
# word:  ##egular   with similarity:  0.143704
# word:  towards   with similarity:  0.14255132
# Dissimilar: mous -0.15456465
#
# x
#
# similar words:
# word:  wailing   with similarity:  0.5444492
# word:  vicious   with similarity:  0.5122315
# word:  material   with similarity:  0.49179506
# Dissimilar: pakistan -0.3311712
#
# y
#
# similar words:
# word:  construc   with similarity:  0.15773785
# word:  squa   with similarity:  0.15030217
# word:  ##eveal   with similarity:  0.1413188
# Dissimilar: nake -0.17476541
#
# z
#
# similar words:
# word:  papermakeupstamps   with similarity:  0.7039716
# word:  newrhinegargoyle   with similarity:  0.70031536
# word:  afaerytaleinmakebelieve   with similarity:  0.69816613
# Dissimilar: personality -0.34717286
#
# ex
#
# similar words:
# word:  ##sert   with similarity:  0.17263955
# word:  nud   with similarity:  0.13343972
# word:  ##esolv   with similarity:  0.1311914
# Dissimilar: edit -0.16405192
#
# xx
#
# similar words:
# word:  xelliealicex   with similarity:  0.6571877
# word:  entire   with similarity:  0.4196415
# word:  oils   with similarity:  0.41742784
# Dissimilar: honoured -0.3940961
#
# ##zz
#
# similar words:
# word:  fanta   with similarity:  0.17097539
# word:  enthra   with similarity:  0.16197318
# word:  ##hi   with similarity:  0.15351446
# Dissimilar: ##tion -0.14308397
#
# ##qu
#
# similar words:
# word:  ##ntation   with similarity:  0.15730259
# word:  evaluating   with similarity:  0.15720302
# word:  boundarie   with similarity:  0.1396206
# Dissimilar: every -0.14441596
#
# bq
#
# similar words:
# word:  ##llect   with similarity:  0.15530531
# word:  drie   with similarity:  0.14180219
# word:  ##tia   with similarity:  0.13946602
# Dissimilar: dayca -0.17406076
#
# bqf
#
# similar words:
# word:  ##lywood   with similarity:  0.14543231
# word:  constantl   with similarity:  0.13824812
# word:  distra   with similarity:  0.13038597
# Dissimilar: ##timony -0.170795
#
# bqff
#
# similar words:
# word:  intend   with similarity:  0.813457
# word:  bull   with similarity:  0.8098184
# word:  knock   with similarity:  0.780916
# Dissimilar: east -0.570932
#
# qu
#
# similar words:
# word:  ##tagra   with similarity:  0.15495011
# word:  ##cow   with similarity:  0.15009621
# word:  ##orous   with similarity:  0.13653147
# Dissimilar: guys -0.16006821
#
# of
#
# similar words:
# word:  fabric   with similarity:  0.48904383
# word:  hedge   with similarity:  0.4863891
# word:  freaked   with similarity:  0.48638564
# Dissimilar: today -0.28785327
#
# ev
#
# similar words:
# word:  ##nsity   with similarity:  0.16093242
# word:  ##ikk   with similarity:  0.14398208
# word:  ##lugg   with similarity:  0.14148849
# Dissimilar: ##athizing -0.15646842
#
# equ
#
# similar words:
# word:  ##tomach   with similarity:  0.14992589
# word:  suppo   with similarity:  0.14956948
# word:  ##sault   with similarity:  0.14548582
# Dissimilar: unencumbered -0.14293247
#
# exp
#
# similar words:
# word:  gov   with similarity:  0.1764539
# word:  policem   with similarity:  0.15235397
# word:  scratche   with similarity:  0.14752749
# Dissimilar: impractica -0.16055207
#
# up
#
# similar words:
# word:  grass   with similarity:  0.40700638
# word:  motors   with similarity:  0.40409037
# word:  ebayed   with similarity:  0.3926568
# Dissimilar: peaceful -0.1992752
#
# ju
#
# similar words:
# word:  his   with similarity:  0.15667927
# word:  ##huma   with similarity:  0.15377069
# word:  standar   with similarity:  0.13817576
# Dissimilar: ##mors -0.16285953
#
# ##bj
#
# similar words:
# word:  dig   with similarity:  0.15293401
# word:  ##orknob   with similarity:  0.14917925
# word:  tools   with similarity:  0.14145185
# Dissimilar: thinne -0.13912514
#
# ##ubj
#
# similar words:
# word:  ##randing   with similarity:  0.14921404
# word:  bir   with similarity:  0.13907367
# word:  curio   with similarity:  0.13354084
# Dissimilar: loneliness -0.16576579
#
# obj
#
# similar words:
# word:  sides   with similarity:  0.16332689
# word:  ##erapist   with similarity:  0.15905204
# word:  austr   with similarity:  0.14687426
# Dissimilar: rather -0.14608212
#
# subj
#
# similar words:
# word:  ##mos   with similarity:  0.14255047
# word:  ##ary   with similarity:  0.14248489
# word:  pro   with similarity:  0.13651504
# Dissimilar: comfo -0.15693054
#
# jus
#
# similar words:
# word:  dirty   with similarity:  0.18066144
# word:  ##ub   with similarity:  0.17042047
# word:  bookmark   with similarity:  0.15675554
# Dissimilar: ##sona -0.14628452
#
# jum
#
# similar words:
# word:  energe   with similarity:  0.1560165
# word:  distrus   with similarity:  0.1470819
# word:  relaxing   with similarity:  0.14391312
# Dissimilar: iphon -0.14046139
#
# jump
#
# similar words:
# word:  ##a   with similarity:  0.7806083
# word:  stay   with similarity:  0.77308786
# word:  seem   with similarity:  0.77076024
# Dissimilar: east -0.46003962
#
# jumb
#
# similar words:
# word:  compr   with similarity:  0.16594502
# word:  dats   with similarity:  0.14536253
# word:  zambia   with similarity:  0.14239685
# Dissimilar: ##torical -0.17576966
#
# exc
#
# similar words:
# word:  grandmothers   with similarity:  0.15532823
# word:  guide   with similarity:  0.15366107
# word:  socks   with similarity:  0.15251838
# Dissimilar: ##etually -0.14392252
#
# ##zzy
#
# similar words:
# word:  ##yond   with similarity:  0.16301522
# word:  ##sua   with similarity:  0.15495504
# word:  everytime   with similarity:  0.14820966
# Dissimilar: beat -0.17199752
#
# jub
#
# similar words:
# word:  amuse   with similarity:  0.1638235
# word:  southe   with similarity:  0.13784498
# word:  cheer   with similarity:  0.13297555
# Dissimilar: ##escrib -0.15767829
#
# jumbl
#
# similar words:
# word:  hedge   with similarity:  0.17175882
# word:  by   with similarity:  0.15073924
# word:  icy   with similarity:  0.14948602
# Dissimilar: ##rican -0.14979851
#
# ##uzz
#
# similar words:
# word:  ##tbrok   with similarity:  0.15339883
# word:  ##san   with similarity:  0.1469124
# word:  forgo   with similarity:  0.14406992
# Dissimilar: ash -0.15219903
#
# puzz
#
# similar words:
# word:  ##tho   with similarity:  0.18633044
# word:  audi   with similarity:  0.14032918
# word:  ##sistant   with similarity:  0.13937704
# Dissimilar: langua -0.14978057
#
# puzzl
#
# similar words:
# word:  deferring   with similarity:  0.15280738
# word:  unfait   with similarity:  0.15090755
# word:  thrillers   with similarity:  0.1458453
# Dissimilar: hyd -0.14102054
#
# equa
#
# similar words:
# word:  facilita   with similarity:  0.14620045
# word:  ##mwor   with similarity:  0.14501071
# word:  ##ets   with similarity:  0.1441388
# Dissimilar: dumpe -0.15285915
#
# jubi
#
# similar words:
# word:  eulalia   with similarity:  0.15234435
# word:  ##ination   with similarity:  0.14266787
# word:  ##moriz   with similarity:  0.139191
# Dissimilar: continu -0.147621
#
# jubil
#
# similar words:
# word:  belittl   with similarity:  0.1435823
# word:  ##alizing   with similarity:  0.14246355
# word:  vulne   with similarity:  0.14198112
# Dissimilar: memorize -0.14218615
#
# jubila
#
# similar words:
# word:  ##trong   with similarity:  0.15345533
# word:  ##eport   with similarity:  0.14195205
# word:  crunch   with similarity:  0.14054777
# Dissimilar: pav -0.15610889
#
# just
#
# similar words:
# word:  marry   with similarity:  0.4507863
# word:  definitely   with similarity:  0.4163212
# word:  unattainable   with similarity:  0.40013966
# Dissimilar: difficult -0.3280626
#
# ##uzzy
#
# similar words:
# word:  ##unstabl   with similarity:  0.15951343
# word:  academic   with similarity:  0.15861534
# word:  disregarded   with similarity:  0.15125841
# Dissimilar: ##ssly -0.14494081
#
# buzzy
#
# similar words:
# word:  periods   with similarity:  0.7093773
# word:  tons   with similarity:  0.7025655
# word:  workouts   with similarity:  0.6934282
# Dissimilar: antics -0.36728832
#
# fuzzy
#
# similar words:
# word:  independence   with similarity:  0.6201323
# word:  drama   with similarity:  0.5882478
# word:  exceptionally   with similarity:  0.57747686
# Dissimilar: them -0.46822906
#
# ##izzy
#
# similar words:
# word:  obliga   with similarity:  0.17460197
# word:  canva   with similarity:  0.15642464
# word:  ##appy   with similarity:  0.15274687
# Dissimilar: unknow -0.17039436
#
# dizzy
#
# similar words:
# word:  shortly   with similarity:  0.76370716
# word:  isabella   with similarity:  0.7215353
# word:  stare   with similarity:  0.721118
# Dissimilar: personality -0.5075976
#
# lizzy
#
# similar words:
# word:  brought   with similarity:  0.7828123
# word:  senator   with similarity:  0.71766114
# word:  spurring   with similarity:  0.70803607
# Dissimilar: ntoward -0.48149735
#
# xb
#
# similar words:
# word:  detatch   with similarity:  0.15524757
# word:  attractiv   with similarity:  0.14424208
# word:  crais   with similarity:  0.1421277
# Dissimilar: flashes -0.1558015
#
# xbl
#
# similar words:
# word:  ##rich   with similarity:  0.1512903
# word:  gall   with similarity:  0.14306352
# word:  psychopatholo   with similarity:  0.12710306
# Dissimilar: ##elating -0.14794084
#
# xbla
#
# similar words:
# word:  medicine   with similarity:  0.678908
# word:  radio   with similarity:  0.6550847
# word:  motion   with similarity:  0.63726765
# Dissimilar: disillusioned -0.42085332
#
# th
#
# similar words:
# word:  birthdays   with similarity:  0.69187874
# word:  invincible   with similarity:  0.594784
# word:  hgtv   with similarity:  0.59423614
# Dissimilar: else -0.3107404
#
# jubilan
#
# similar words:
# word:  ##port   with similarity:  0.14114736
# word:  ##nto   with similarity:  0.13698071
# word:  ##enounc   with similarity:  0.13488846
# Dissimilar: ##lings -0.14007463
#
# jubilant
#
# similar words:
# word:  unsafe   with similarity:  0.9778106
# word:  hyper   with similarity:  0.97700214
# word:  spiteful   with similarity:  0.96960884
# Dissimilar: personality -0.6293863
#
# my
#
# similar words:
# word:  mai   with similarity:  0.52015
# word:  recipes   with similarity:  0.51132977
# word:  zoned   with similarity:  0.5018881
# Dissimilar: game -0.34993562
#
# ov
#
# similar words:
# word:  amusement   with similarity:  0.18446217
# word:  our   with similarity:  0.1779744
# word:  outdoors   with similarity:  0.15411262
# Dissimilar: thatrupert -0.14713706
#
# ##pp
#
# similar words:
# word:  trimming   with similarity:  0.17083064
# word:  grac   with similarity:  0.16100633
# word:  ##raining   with similarity:  0.14953192
# Dissimilar: statis -0.15118052
#
# qui
#
# similar words:
# word:  cheerleade   with similarity:  0.15613359
# word:  ##astically   with similarity:  0.15387404
# word:  scre   with similarity:  0.15015462
# Dissimilar: art -0.15155442
#
# wh
#
# similar words:
# word:  verrrrrrrryyyy   with similarity:  0.6963764
# word:  initiation   with similarity:  0.68541133
# word:  ridiculously   with similarity:  0.5050426
# Dissimilar: peep -0.6607072
#
# quit
#
# similar words:
# word:  goodwill   with similarity:  0.9036343
# word:  ini   with similarity:  0.8742833
# word:  indicated   with similarity:  0.8710499
# Dissimilar: personality -0.52328146
#
# quic
#
# similar words:
# word:  ##gular   with similarity:  0.1464959
# word:  captu   with similarity:  0.14201146
# word:  ##forming   with similarity:  0.13216266
# Dissimilar: ##visibl -0.17853433
#
# quick
#
# similar words:
# word:  commi   with similarity:  0.16613373
# word:  china   with similarity:  0.15669493
# word:  war   with similarity:  0.14820682
# Dissimilar: kiyosh -0.14636286
#
# quickl
#
# similar words:
# word:  seems   with similarity:  0.15916348
# word:  ##esserts   with similarity:  0.15089057
# word:  riding   with similarity:  0.15035477
# Dissimilar: congr -0.18223475
#
# quickly
#
# similar words:
# word:  evident   with similarity:  0.7467848
# word:  challenge   with similarity:  0.6988975
# word:  club   with similarity:  0.6737008
# Dissimilar: unconsciously -0.4912113
#
# quiv
#
# similar words:
# word:  mightily   with similarity:  0.15864183
# word:  ##ajubi   with similarity:  0.14907569
# word:  ##ero   with similarity:  0.13428329
# Dissimilar: ##reka -0.16069928
#
# ##azz
#
# similar words:
# word:  ##thletics   with similarity:  0.17908022
# word:  ##adua   with similarity:  0.15905339
# word:  montana   with similarity:  0.15380469
# Dissimilar: ##mally -0.16233201
#
# dazz
#
# similar words:
# word:  ##ayou   with similarity:  0.15571676
# word:  thri   with similarity:  0.15196717
# word:  ##complish   with similarity:  0.15086243
# Dissimilar: heading -0.15896651
#
# ##pazz
#
# similar words:
# word:  gr   with similarity:  0.15347184
# word:  portr   with similarity:  0.14090176
# word:  tb   with similarity:  0.1406588
# Dissimilar: ##ondmu -0.15761188
#
# spazz
#
# similar words:
# word:  ##bsit   with similarity:  0.17440465
# word:  spiral   with similarity:  0.15720682
# word:  freakishly   with similarity:  0.14712204
# Dissimilar: dancing -0.1697532
#
# dazzl
#
# similar words:
# word:  asid   with similarity:  0.16876495
# word:  ##sochi   with similarity:  0.1635416
# word:  ##rblon   with similarity:  0.14766312
# Dissimilar: ##ish -0.16312896
#
# dazzli
#
# similar words:
# word:  rebuilding   with similarity:  0.15556887
# word:  nic   with similarity:  0.15517765
# word:  ##ndon   with similarity:  0.14628015
# Dissimilar: intense -0.1874327
#
# ##izz
#
# similar words:
# word:  afaerytaleinmakebeliev   with similarity:  0.15171818
# word:  ##iiifff   with similarity:  0.14384523
# word:  ##eadings   with similarity:  0.1326999
# Dissimilar: ##stly -0.14783461
#
# ##rizz
#
# similar words:
# word:  disillusion   with similarity:  0.16829774
# word:  artisan   with similarity:  0.1627746
# word:  mysterious   with similarity:  0.16047114
# Dissimilar: lbs -0.14705572
#
# frizz
#
# similar words:
# word:  laughable   with similarity:  0.88674253
# word:  inarticulate   with similarity:  0.88358486
# word:  firey   with similarity:  0.8615228
# Dissimilar: disillusioned -0.34386715
#
# spazzo
#
# similar words:
# word:  ##alic   with similarity:  0.151115
# word:  ##ting   with similarity:  0.15103777
# word:  erra   with similarity:  0.14966013
# Dissimilar: angr -0.16162202
#
# spazzol
#
# similar words:
# word:  arcad   with similarity:  0.14274696
# word:  ##etflix   with similarity:  0.14228493
# word:  sal   with similarity:  0.13956201
# Dissimilar: psychopatholog -0.16360053
#
# spazzola
#
# similar words:
# word:  ##e   with similarity:  0.61661977
# word:  reveal   with similarity:  0.5973649
# word:  ask   with similarity:  0.5970724
# Dissimilar: americana -0.4055358
#
# dazzlin
#
# similar words:
# word:  ##ngals   with similarity:  0.16443117
# word:  ##dphon   with similarity:  0.1459435
# word:  para   with similarity:  0.14486742
# Dissimilar: priva -0.15633973
#
# dazzling
#
# similar words:
# word:  cert   with similarity:  0.7641343
# word:  shivering   with similarity:  0.76106167
# word:  sigil   with similarity:  0.7019501
# Dissimilar: islam -0.34904355
#
# ##az
#
# similar words:
# word:  consolidatio   with similarity:  0.15981445
# word:  taiwa   with similarity:  0.1538193
# word:  schem   with similarity:  0.1470375
# Dissimilar: shred -0.19815917
#
# ##maz
#
# similar words:
# word:  ##eac   with similarity:  0.14811465
# word:  ough   with similarity:  0.14272127
# word:  str   with similarity:  0.13488075
# Dissimilar: ##sation -0.14358115
#
# daz
#
# similar words:
# word:  ##stakingly   with similarity:  0.13681796
# word:  conspi   with similarity:  0.13264082
# word:  ##rian   with similarity:  0.13138658
# Dissimilar: ##omach -0.16326118
#
# ##azy
#
# similar words:
# word:  restle   with similarity:  0.14234942
# word:  alignc   with similarity:  0.14014025
# word:  divorc   with similarity:  0.13818347
# Dissimilar: ##rything -0.16295859
#
# lazy
#
# similar words:
# word:  sip   with similarity:  0.734786
# word:  smart   with similarity:  0.7132175
# word:  hopeless   with similarity:  0.7066328
# Dissimilar: personality -0.5110439
#
# gaz
#
# similar words:
# word:  ##rself   with similarity:  0.1515707
# word:  quite   with similarity:  0.15156749
# word:  less   with similarity:  0.14457093
# Dissimilar: post -0.1816858
#
# maz
#
# similar words:
# word:  fangi   with similarity:  0.15694188
# word:  disti   with similarity:  0.15510249
# word:  fowar   with similarity:  0.14485654
# Dissimilar: ##ut -0.16015452
#
# haz
#
# similar words:
# word:  ##akup   with similarity:  0.1615654
# word:  organizat   with similarity:  0.15109238
# word:  attitude   with similarity:  0.14633717
# Dissimilar: every -0.16604808
#
# ##gaz
#
# similar words:
# word:  cantank   with similarity:  0.19434062
# word:  possibilit   with similarity:  0.15410392
# word:  patriotis   with similarity:  0.14883472
# Dissimilar: ##coho -0.1690279
#
# amaz
#
# similar words:
# word:  ##riju   with similarity:  0.16586563
# word:  journalism   with similarity:  0.14591561
# word:  ##parat   with similarity:  0.14361894
# Dissimilar: apologis -0.15439859
#
# ##razy
#
# similar words:
# word:  facilita   with similarity:  0.13989282
# word:  ##mmak   with similarity:  0.13855022
# word:  disheartene   with similarity:  0.13352056
# Dissimilar: ##rsing -0.16552004
#
# crazy
#
# similar words:
# word:  addictive   with similarity:  0.69041485
# word:  directly   with similarity:  0.674423
# word:  cook   with similarity:  0.6552191
# Dissimilar: east -0.40729088
#
# ##agaz
#
# similar words:
# word:  ##ap   with similarity:  0.1455808
# word:  ##crib   with similarity:  0.13954884
# word:  freake   with similarity:  0.13801177
# Dissimilar: ##san -0.16432934
#
# magaz
#
# similar words:
# word:  ##elp   with similarity:  0.15712237
# word:  ##ugging   with similarity:  0.15239182
# word:  dayca   with similarity:  0.14688642
# Dissimilar: spie -0.16793954
#
# magazi
#
# similar words:
# word:  ##mpt   with similarity:  0.16056338
# word:  ##rch   with similarity:  0.13307308
# word:  uhu   with similarity:  0.13262182
# Dissimilar: divis -0.16554071
#
# magazin
#
# similar words:
# word:  ##iwa   with similarity:  0.14609444
# word:  disadv   with similarity:  0.13724683
# word:  decembe   with similarity:  0.13577807
# Dissimilar: ove -0.14504531
#
# ##iz
#
# similar words:
# word:  ##lov   with similarity:  0.15562695
# word:  mircowav   with similarity:  0.14836136
# word:  fiction   with similarity:  0.14337873
# Dissimilar: ing -0.1700947
#
# ab
#
# similar words:
# word:  ##gativ   with similarity:  0.1703034
# word:  jasons   with similarity:  0.14813945
# word:  chain   with similarity:  0.14361396
# Dissimilar: ##lirtiing -0.14456682
#
# abo
#
# similar words:
# word:  ##dibly   with similarity:  0.16555864
# word:  ##lation   with similarity:  0.15213127
# word:  ##ycho   with similarity:  0.15145269
# Dissimilar: ##alanc -0.15920404
#
# abou
#
# similar words:
# word:  ##essings   with similarity:  0.14599329
# word:  ##evelopm   with similarity:  0.13802679
# word:  ##inic   with similarity:  0.1364248
# Dissimilar: ##cau -0.1504906
#
# abov
#
# similar words:
# word:  ##eakishly   with similarity:  0.15903965
# word:  popu   with similarity:  0.15763357
# word:  engag   with similarity:  0.13524045
# Dissimilar: ##rapi -0.15071893
#
# about
#
# similar words:
# word:  progressive   with similarity:  0.5375091
# word:  involves   with similarity:  0.45796263
# word:  local   with similarity:  0.40186703
# Dissimilar: lauren -0.26540893
#
# aboun
#
# similar words:
# word:  diminishing   with similarity:  0.16504274
# word:  pres   with similarity:  0.15594432
# word:  ##ku   with similarity:  0.15190348
# Dissimilar: ##attainabl -0.14815615
#
# abound
#
# similar words:
# word:  succeed   with similarity:  0.84651756
# word:  accordance   with similarity:  0.83347005
# word:  throw   with similarity:  0.8261684
# Dissimilar: east -0.5183499
#
# ##upp
#
# similar words:
# word:  self   with similarity:  0.17359191
# word:  nowher   with similarity:  0.15375268
# word:  level   with similarity:  0.15281962
# Dissimilar: hospita -0.16736354
#
# supp
#
# similar words:
# word:  disorga   with similarity:  0.15105742
# word:  ##llions   with similarity:  0.14799461
# word:  apar   with similarity:  0.14290878
# Dissimilar: longingly -0.17473048
#
# pupp
#
# similar words:
# word:  ##aul   with similarity:  0.16208893
# word:  sus   with similarity:  0.15103962
# word:  contrib   with similarity:  0.14463368
# Dissimilar: spontane -0.13713276
#
# puppy
#
# similar words:
# word:  rightly   with similarity:  0.84781927
# word:  serving   with similarity:  0.7899046
# word:  unusually   with similarity:  0.7452196
# Dissimilar: personality -0.47329986
#
# suppo
#
# similar words:
# word:  equ   with similarity:  0.14956948
# word:  ##rug   with similarity:  0.13615322
# word:  ##mpl   with similarity:  0.1352947
# Dissimilar: masochis -0.1481395
#
# suppor
#
# similar words:
# word:  oppr   with similarity:  0.1607902
# word:  reshap   with similarity:  0.14132556
# word:  ##turn   with similarity:  0.14021775
# Dissimilar: revampe -0.15753007
#
# suppos
#
# similar words:
# word:  jasmine   with similarity:  0.16364983
# word:  fuchs   with similarity:  0.15534037
# word:  reveng   with similarity:  0.1406492
# Dissimilar: ##ptiona -0.1641002
#
# support
#
# similar words:
# word:  protection   with similarity:  0.6675718
# word:  shoelace   with similarity:  0.6525531
# word:  soap   with similarity:  0.6492841
# Dissimilar: east -0.5884073
#
# ##ppy
#
# similar words:
# word:  ##esn   with similarity:  0.13963282
# word:  shiv   with similarity:  0.13884717
# word:  ##adio   with similarity:  0.1387881
# Dissimilar: ##engals -0.14126322
#
# ##appy
#
# similar words:
# word:  enjoying   with similarity:  0.16143611
# word:  ##izzy   with similarity:  0.15274687
# word:  unappreciat   with similarity:  0.13898252
# Dissimilar: impati -0.15809028
#
# happy
#
# similar words:
# word:  raising   with similarity:  0.7225944
# word:  yourself   with similarity:  0.7170899
# word:  integrity   with similarity:  0.7070148
# Dissimilar: personality -0.5252451
#
# ##happy
#
# similar words:
# word:  ##ird   with similarity:  0.14094526
# word:  ##lingha   with similarity:  0.1379672
# word:  everywher   with similarity:  0.1348491
# Dissimilar: bliss -0.1423192
#
# ##rappy
#
# similar words:
# word:  traumat   with similarity:  0.16543606
# word:  ##tral   with similarity:  0.15368176
# word:  ##aling   with similarity:  0.15190604
# Dissimilar: ##ruthful -0.1480531
#
# crappy
#
# similar words:
# word:  passionate   with similarity:  0.82596713
# word:  resentful   with similarity:  0.79543066
# word:  roof   with similarity:  0.794998
# Dissimilar: ntoward -0.57745874
#
# opp
#
# similar words:
# word:  ##ptanc   with similarity:  0.15267232
# word:  pursuing   with similarity:  0.1475432
# word:  fans   with similarity:  0.14691347
# Dissimilar: ##aylor -0.1547424
#
# ##nhappy
#
# similar words:
# word:  corn   with similarity:  0.15490487
# word:  ##nxi   with similarity:  0.14647025
# word:  wom   with similarity:  0.14230818
# Dissimilar: zimme -0.16441801
#
# unhappy
#
# similar words:
# word:  minister   with similarity:  0.7426667
# word:  distressed   with similarity:  0.73849666
# word:  supermarket   with similarity:  0.73672646
# Dissimilar: ntoward -0.5946464
#
# oppo
#
# similar words:
# word:  boyfrie   with similarity:  0.16337281
# word:  ##ob   with similarity:  0.14886856
# word:  ##gorous   with similarity:  0.14618576
# Dissimilar: accord -0.16370904
#
# oppr
#
# similar words:
# word:  suppor   with similarity:  0.1607902
# word:  saddene   with similarity:  0.1553443
# word:  simila   with similarity:  0.14933634
# Dissimilar: xd -0.15176454
#
# oppor
#
# similar words:
# word:  ##estroying   with similarity:  0.15197381
# word:  ##astforwarding   with similarity:  0.13509893
# word:  ##ilmmak   with similarity:  0.1339351
# Dissimilar: twi -0.14294949
#
# oppos
#
# similar words:
# word:  bitte   with similarity:  0.1583992
# word:  unknown   with similarity:  0.14570886
# word:  pav   with similarity:  0.14034523
# Dissimilar: opportun -0.1545092
#
# opport
#
# similar words:
# word:  clai   with similarity:  0.1522697
# word:  squa   with similarity:  0.13212666
# word:  unfor   with similarity:  0.1320615
# Dissimilar: sain -0.15648256
#
# opportu
#
# similar words:
# word:  ##egs   with similarity:  0.15714373
# word:  juli   with similarity:  0.14256166
# word:  ##ep   with similarity:  0.14148375
# Dissimilar: ##unching -0.14974964
#
# opportun
#
# similar words:
# word:  ##nmark   with similarity:  0.16165832
# word:  ##ndh   with similarity:  0.14667805
# word:  ##latform   with similarity:  0.14099365
# Dissimilar: apar -0.15868369
#
# opportuni
#
# similar words:
# word:  ##ccor   with similarity:  0.14095512
# word:  ##ever   with similarity:  0.13839081
# word:  ##reacting   with similarity:  0.13537632
# Dissimilar: ##lliealicex -0.14916287
#
# opportunit
#
# similar words:
# word:  ##rybodys   with similarity:  0.15998688
# word:  ##rugg   with similarity:  0.14607354
# word:  ##ldom   with similarity:  0.14398105
# Dissimilar: triangl -0.1527615
#
# opportunity
#
# similar words:
# word:  led   with similarity:  0.70715034
# word:  module   with similarity:  0.70538086
# word:  accustomed   with similarity:  0.68607384
# Dissimilar: east -0.48896182
#
# opposi
#
# similar words:
# word:  pond   with similarity:  0.15028602
# word:  discou   with similarity:  0.13526347
# word:  ##ellig   with similarity:  0.13465337
# Dissimilar: dumpe -0.15504101
#
# opposit
#
# similar words:
# word:  ##estl   with similarity:  0.17798503
# word:  ##rrit   with similarity:  0.15768632
# word:  enthu   with similarity:  0.1327505
# Dissimilar: ##nxious -0.19106993
#
# supporti
#
# similar words:
# word:  corne   with similarity:  0.15170002
# word:  agi   with similarity:  0.13957599
# word:  failur   with similarity:  0.13656174
# Dissimilar: ##alli -0.16264337
#
# supportiv
#
# similar words:
# word:  hus   with similarity:  0.16554433
# word:  ##uccumb   with similarity:  0.15293714
# word:  ##strang   with similarity:  0.14547083
# Dissimilar: consolidati -0.1889886
#
# supportin
#
# similar words:
# word:  whis   with similarity:  0.13881761
# word:  ##eteriorat   with similarity:  0.12978211
# word:  exhibitioni   with similarity:  0.1291467
# Dissimilar: dub -0.15584391
#
# supporting
#
# similar words:
# word:  relocating   with similarity:  0.5768051
# word:  droves   with similarity:  0.5403305
# word:  actions   with similarity:  0.5277086
# Dissimilar: rustie -0.3640862
#
# yo
#
# similar words:
# word:  traditionalist   with similarity:  0.15343058
# word:  ciga   with similarity:  0.14794064
# word:  stripp   with similarity:  0.14194614
# Dissimilar: uh -0.1639218
#
# you
#
# similar words:
# word:  they   with similarity:  0.56641686
# word:  we   with similarity:  0.5502589
# word:  statistics   with similarity:  0.5106038
# Dissimilar: unconsciously -0.29239178
#
# yor
#
# similar words:
# word:  consign   with similarity:  0.16727047
# word:  distan   with similarity:  0.16301778
# word:  ##nsation   with similarity:  0.1582233
# Dissimilar: ##tforwarding -0.1647575
#
# york
#
# similar words:
# word:  situations   with similarity:  0.67104465
# word:  indonesia   with similarity:  0.5535235
# word:  stage   with similarity:  0.51989484
# Dissimilar: hath -0.36555153
#
# yog
#
# similar words:
# word:  ##cializing   with similarity:  0.17978263
# word:  eyed   with similarity:  0.16422892
# word:  influenced   with similarity:  0.16395245
# Dissimilar: ##edicin -0.14722005
#
# yoga
#
# similar words:
# word:  anger   with similarity:  0.76685715
# word:  bounces   with similarity:  0.7608801
# word:  worthwhile   with similarity:  0.7361282
# Dissimilar: ntoward -0.60199374
#
# squ
#
# similar words:
# word:  atmosphe   with similarity:  0.1499725
# word:  ##lings   with similarity:  0.14809543
# word:  ##minist   with similarity:  0.14196074
# Dissimilar: ##sgiving -0.17649171
#
# exci
#
# similar words:
# word:  ##as   with similarity:  0.1596271
# word:  ##abour   with similarity:  0.15709415
# word:  ##truction   with similarity:  0.15253901
# Dissimilar: recomme -0.15667917
#
# excit
#
# similar words:
# word:  ##stimony   with similarity:  0.16245246
# word:  ungra   with similarity:  0.16082716
# word:  ##sent   with similarity:  0.15961635
# Dissimilar: ##ertainly -0.15039638
#
# app
#
# similar words:
# word:  ##arm   with similarity:  0.16198178
# word:  disr   with similarity:  0.14069404
# word:  ##cifical   with similarity:  0.13775042
# Dissimilar: ##conomy -0.14460957
#
# ##app
#
# similar words:
# word:  mix   with similarity:  0.15450019
# word:  mov   with similarity:  0.14200583
# word:  brothe   with similarity:  0.134229
# Dissimilar: ##f -0.16615728
#
# happ
#
# similar words:
# word:  bridal   with similarity:  0.15363482
# word:  booth   with similarity:  0.15340655
# word:  ##sul   with similarity:  0.15311739
# Dissimilar: desp -0.14627321
#
# ##sapp
#
# similar words:
# word:  ##ring   with similarity:  0.15713117
# word:  ##employm   with similarity:  0.15272973
# word:  ##auti   with similarity:  0.14374104
# Dissimilar: to -0.17089725
#
# capp
#
# similar words:
# word:  pounding   with similarity:  0.96671045
# word:  accidentally   with similarity:  0.9449178
# word:  ba   with similarity:  0.94304836
# Dissimilar: ntoward -0.66295916
#
# lapp
#
# similar words:
# word:  ##edically   with similarity:  0.18646136
# word:  compensate   with similarity:  0.14963678
# word:  ##lubb   with similarity:  0.14400369
# Dissimilar: dramatically -0.15549192
#
# ##isapp
#
# similar words:
# word:  ##ronto   with similarity:  0.15613121
# word:  ##as   with similarity:  0.15355596
# word:  ##troduc   with similarity:  0.14280254
# Dissimilar: rosli -0.14289069
#
# disapp
#
# similar words:
# word:  powde   with similarity:  0.16711256
# word:  worr   with similarity:  0.15236135
# word:  v   with similarity:  0.14852181
# Dissimilar: ##thoo -0.14299983
#
# lappi
#
# similar words:
# word:  curre   with similarity:  0.14962944
# word:  ##rtic   with similarity:  0.13769415
# word:  ##ck   with similarity:  0.13556029
# Dissimilar: ##mini -0.14042765
#
# ##rapp
#
# similar words:
# word:  nak   with similarity:  0.15233254
# word:  unfit   with similarity:  0.1506097
# word:  ##gum   with similarity:  0.14752558
# Dissimilar: americas -0.15574928
#
# grapp
#
# similar words:
# word:  hoho   with similarity:  0.14659005
# word:  ##sit   with similarity:  0.14352843
# word:  fowa   with similarity:  0.14149229
# Dissimilar: ##mph -0.16150767
#
# wrapp
#
# similar words:
# word:  ##tiff   with similarity:  0.1767126
# word:  ##elligence   with similarity:  0.14837664
# word:  ##ag   with similarity:  0.1440238
# Dissimilar: ##elationship -0.19012229
#
# ##appr
#
# similar words:
# word:  disciples   with similarity:  0.1401396
# word:  deform   with similarity:  0.13709113
# word:  bunion   with similarity:  0.1365682
# Dissimilar: peoples -0.14488304
#
# grappl
#
# similar words:
# word:  mrdanbai   with similarity:  0.15399584
# word:  urg   with similarity:  0.13143179
# word:  riders   with similarity:  0.13119695
# Dissimilar: ##eactions -0.14776278
#
# grappli
#
# similar words:
# word:  ##owth   with similarity:  0.15382022
# word:  moo   with similarity:  0.1464493
# word:  ##eopl   with similarity:  0.13778558
# Dissimilar: darkn -0.17102179
#
# grapplin
#
# similar words:
# word:  charac   with similarity:  0.16426837
# word:  ##nos   with similarity:  0.15381101
# word:  duk   with similarity:  0.15231225
# Dissimilar: ##iday -0.14946382
#
# grappling
#
# similar words:
# word:  senator   with similarity:  0.7927572
# word:  struggle   with similarity:  0.7531588
# word:  empathize   with similarity:  0.7484638
# Dissimilar: ntoward -0.4853791
#
# lappin
#
# similar words:
# word:  evi   with similarity:  0.16696209
# word:  supr   with similarity:  0.15855493
# word:  grandfathe   with similarity:  0.14707631
# Dissimilar: ##havior -0.14259563
#
# lapping
#
# similar words:
# word:  torso   with similarity:  0.62415063
# word:  skeleton   with similarity:  0.56029385
# word:  water   with similarity:  0.54956347
# Dissimilar: casually -0.39811653
#
# ##nappr
#
# similar words:
# word:  spiritualit   with similarity:  0.14050618
# word:  ativan   with similarity:  0.13931318
# word:  ##esson   with similarity:  0.13755552
# Dissimilar: ##ntermarrying -0.16444024
#
# unappr
#
# similar words:
# word:  ##ictiv   with similarity:  0.19216497
# word:  ##ictabl   with similarity:  0.1496328
# word:  declin   with similarity:  0.14873825
# Dissimilar: unfold -0.17026025
#
# appr
#
# similar words:
# word:  ##eg   with similarity:  0.15265068
# word:  midter   with similarity:  0.14065707
# word:  banishe   with similarity:  0.13930789
# Dissimilar: ##vent -0.1626849
#
# disappo
#
# similar words:
# word:  nutritional   with similarity:  0.1454124
# word:  ##war   with similarity:  0.14483747
# word:  ##urious   with similarity:  0.13928036
# Dissimilar: partnership -0.15359768
#
# disappoi
#
# similar words:
# word:  ##tuck   with similarity:  0.17771554
# word:  ##tching   with similarity:  0.16424385
# word:  oppre   with similarity:  0.14505908
# Dissimilar: entire -0.17914858
#
# disappoin
#
# similar words:
# word:  machin   with similarity:  0.15383394
# word:  charact   with similarity:  0.14951225
# word:  ##errific   with similarity:  0.137598
# Dissimilar: posse -0.16530411
#
# disappoint
#
# similar words:
# word:  bless   with similarity:  0.816157
# word:  relax   with similarity:  0.7866354
# word:  fuck   with similarity:  0.77336
# Dissimilar: instructions -0.4691676
#
# disappointm
#
# similar words:
# word:  ##troying   with similarity:  0.16981071
# word:  vort   with similarity:  0.15185997
# word:  copie   with similarity:  0.1485091
# Dissimilar: ##neath -0.14332944
#
# ##mp
#
# similar words:
# word:  fluffed   with similarity:  0.15341352
# word:  loca   with similarity:  0.14478698
# word:  fastforwarding   with similarity:  0.14404693
# Dissimilar: ##mploy -0.15790972
#
# emp
#
# similar words:
# word:  ##scu   with similarity:  0.14005475
# word:  supermark   with similarity:  0.13908443
# word:  ##eamworld   with similarity:  0.13779074
# Dissimilar: grandios -0.15167111
#
# ##opp
#
# similar words:
# word:  emb   with similarity:  0.15624838
# word:  nowhe   with similarity:  0.14586557
# word:  ##lack   with similarity:  0.14530036
# Dissimilar: trafford -0.19904563
#
# copp
#
# similar words:
# word:  ##sponsibiliti   with similarity:  0.15670508
# word:  interpreted   with similarity:  0.15119976
# word:  countr   with similarity:  0.1479024
# Dissimilar: ##uctiv -0.15228456
#
# ##hopp
#
# similar words:
# word:  peacefuln   with similarity:  0.16583943
# word:  polar   with similarity:  0.16494732
# word:  ##verag   with similarity:  0.14535397
# Dissimilar: ##elpful -0.17525879
#
# shopp
#
# similar words:
# word:  ##arriag   with similarity:  0.20388553
# word:  ##eck   with similarity:  0.15447642
# word:  ##endence   with similarity:  0.14980508
# Dissimilar: ##oom -0.16047269
#
# popp
#
# similar words:
# word:  shape   with similarity:  0.14928664
# word:  ##eriing   with similarity:  0.14468041
# word:  whitley   with similarity:  0.14438242
# Dissimilar: ##raining -0.15162924
#
# shoppi
#
# similar words:
# word:  ##rizing   with similarity:  0.17090712
# word:  ##rastically   with similarity:  0.15502574
# word:  frequ   with similarity:  0.15006153
# Dissimilar: ec -0.1504942
#
# ##ipp
#
# similar words:
# word:  childr   with similarity:  0.14066368
# word:  ##ratur   with similarity:  0.13792302
# word:  ##yond   with similarity:  0.13692318
# Dissimilar: communica -0.16109635
#
# ripp
#
# similar words:
# word:  consolidation   with similarity:  0.17493576
# word:  yours   with similarity:  0.17299113
# word:  comings   with similarity:  0.17104432
# Dissimilar: ##phon -0.18636194
#
# rippl
#
# similar words:
# word:  talk   with similarity:  0.15899321
# word:  ##nanc   with similarity:  0.15538727
# word:  sarcas   with similarity:  0.14566666
# Dissimilar: ##eartsick -0.16660471
#
# rippli
#
# similar words:
# word:  ##vativ   with similarity:  0.15603653
# word:  ##marrying   with similarity:  0.1526446
# word:  ##tandh   with similarity:  0.13785112
# Dissimilar: disg -0.15804774
#
# ##lipp
#
# similar words:
# word:  ##randing   with similarity:  0.14812477
# word:  ##imp   with similarity:  0.14591706
# word:  cartwhe   with similarity:  0.14542219
# Dissimilar: ##ptiona -0.18693507
#
# slipp
#
# similar words:
# word:  ##nsion   with similarity:  0.14472476
# word:  ##yboar   with similarity:  0.13325946
# word:  ##cu   with similarity:  0.13026854
# Dissimilar: neth -0.18813652
#
# flipp
#
# similar words:
# word:  woven   with similarity:  0.1752775
# word:  fear   with similarity:  0.1735076
# word:  unheard   with similarity:  0.16552116
# Dissimilar: pill -0.1508648
#
# ##ripp
#
# similar words:
# word:  ##dication   with similarity:  0.15376547
# word:  accessari   with similarity:  0.15077178
# word:  ##altic   with similarity:  0.15029475
# Dissimilar: argue -0.14591034
#
# ##tripp
#
# similar words:
# word:  ##vin   with similarity:  0.18713951
# word:  apolog   with similarity:  0.17486942
# word:  bal   with similarity:  0.16613011
# Dissimilar: ##epths -0.17271104
#
# stripp
#
# similar words:
# word:  treasur   with similarity:  0.15460785
# word:  plagu   with similarity:  0.15252653
# word:  integrate   with similarity:  0.15068977
# Dissimilar: ##ssary -0.15631528
#
# shoppin
#
# similar words:
# word:  ##kish   with similarity:  0.16601875
# word:  cowor   with similarity:  0.15258382
# word:  ##alous   with similarity:  0.14664629
# Dissimilar: reaffirme -0.13090186
#
# shopping
#
# similar words:
# word:  stepped   with similarity:  0.76234263
# word:  pokes   with similarity:  0.75271964
# word:  drop   with similarity:  0.74122006
# Dissimilar: ntoward -0.6845659
#
# ripplin
#
# similar words:
# word:  ##attl   with similarity:  0.16562924
# word:  ##l   with similarity:  0.15314843
# word:  activ   with similarity:  0.15217969
# Dissimilar: ##spous -0.17637698
#
# rippling
#
# similar words:
# word:  prohibition   with similarity:  0.77524996
# word:  cherish   with similarity:  0.7709818
# word:  carelessness   with similarity:  0.75834244
# Dissimilar: east -0.56478834
#
# ##topp
#
# similar words:
# word:  welfar   with similarity:  0.13570458
# word:  lightheade   with similarity:  0.13481691
# word:  ##mplo   with similarity:  0.1326573
# Dissimilar: ##erself -0.16782068
#
# stopp
#
# similar words:
# word:  charmed   with similarity:  0.14381017
# word:  apron   with similarity:  0.1404402
# word:  button   with similarity:  0.13924336
# Dissimilar: ##taff -0.14778261
#
# topp
#
# similar words:
# word:  ##tash   with similarity:  0.14914414
# word:  surr   with similarity:  0.14134288
# word:  palin   with similarity:  0.13507688
# Dissimilar: ##lond -0.1762913
#
# ##ropp
#
# similar words:
# word:  aiml   with similarity:  0.14790711
# word:  childhoo   with similarity:  0.14098392
# word:  ##ywh   with similarity:  0.13960461
# Dissimilar: thems -0.1484676
#
# dropp
#
# similar words:
# word:  quiltc   with similarity:  0.1544699
# word:  ##augh   with similarity:  0.1412116
# word:  nai   with similarity:  0.14094599
# Dissimilar: appreciat -0.1574331
#
# droppi
#
# similar words:
# word:  reshape   with similarity:  0.1420157
# word:  extra   with similarity:  0.1410496
# ...
#
# similar words:
# word:  clara   with similarity:  0.79090387
# word:  spoon   with similarity:  0.76005626
# word:  dryers   with similarity:  0.74597174
# Dissimilar: east -0.5254893
#
# watchers
#
# similar words:
# word:  trimester   with similarity:  0.66047275
# word:  meditated   with similarity:  0.63782096
# word:  economy   with similarity:  0.6317248
# Dissimilar: prank -0.3301965
#
# supporters
#
# similar words:
# word:  sinks   with similarity:  0.75920415
# word:  satan   with similarity:  0.7503611
# word:  anna   with similarity:  0.74687964
# Dissimilar: understad -0.38006732
#
# shoulders
#
# similar words:
# word:  wig   with similarity:  0.8294228
# word:  ankle   with similarity:  0.82806957
# word:  soulmate   with similarity:  0.78539515
# Dissimilar: east -0.5631834
#
# workers
#
# similar words:
# word:  co   with similarity:  0.64609826
# word:  situations   with similarity:  0.5963634
# word:  apologise   with similarity:  0.58108485
# Dissimilar: personality -0.28869307
#
# nighters
#
# similar words:
# word:  velvet   with similarity:  0.6783811
# word:  fluffed   with similarity:  0.61962867
# word:  somewhere   with similarity:  0.60593534
# Dissimilar: ntoward -0.44953507
#
# offers
#
# similar words:
# word:  cousin   with similarity:  0.60775375
# word:  dragging   with similarity:  0.5609321
# word:  limbs   with similarity:  0.5566361
# Dissimilar: east -0.39495975
#
# downers
#
# similar words:
# word:  believing   with similarity:  0.82127774
# word:  trigger   with similarity:  0.7754644
# word:  lacking   with similarity:  0.77176154
# Dissimilar: ntoward -0.56831956
#
# users
#
# similar words:
# word:  trips   with similarity:  0.61077243
# word:  sight   with similarity:  0.53721774
# word:  coerce   with similarity:  0.5311775
# Dissimilar: bein -0.40305084
#
# mrs
#
# similar words:
# word:  showing   with similarity:  0.6106373
# word:  rod   with similarity:  0.5698683
# word:  gs   with similarity:  0.5645902
# Dissimilar: jimmys -0.37146455
#
# ##ners
#
# similar words:
# word:  fak   with similarity:  0.1626726
# word:  fulf   with similarity:  0.1494984
# word:  ##ereka   with similarity:  0.1438564
# Dissimilar: circumstanc -0.13966931
#
# ##eaders
#
# similar words:
# word:  ##tashing   with similarity:  0.15588474
# word:  attainable   with similarity:  0.15417837
# word:  deteriorate   with similarity:  0.14537263
# Dissimilar: humb -0.15557438
#
# readers
#
# similar words:
# word:  loyal   with similarity:  0.7610325
# word:  agreed   with similarity:  0.6536727
# word:  rest   with similarity:  0.6073263
# Dissimilar: seldom -0.42211854
#
# ##eers
#
# similar words:
# word:  halloween   with similarity:  0.15882058
# word:  zimme   with similarity:  0.1403507
# word:  ##usiv   with similarity:  0.13458362
# Dissimilar: funds -0.19175267
#
# peers
#
# similar words:
# word:  typical   with similarity:  0.7837932
# word:  lamb   with similarity:  0.51469815
# word:  egypt   with similarity:  0.4869876
# Dissimilar: o -0.30442697
#
# careers
#
# similar words:
# word:  lightly   with similarity:  0.5747064
# word:  manageable   with similarity:  0.5556532
# word:  flow   with similarity:  0.5417341
# Dissimilar: possession -0.3493446
#
# ##eners
#
# similar words:
# word:  busine   with similarity:  0.15981884
# word:  chap   with similarity:  0.15768582
# word:  taken   with similarity:  0.15126804
# Dissimilar: impu -0.15390357
#
# sweeteners
#
# similar words:
# word:  browsers   with similarity:  0.59304774
# word:  inquire   with similarity:  0.5740156
# word:  bundle   with similarity:  0.5683404
# Dissimilar: seldom -0.32018048
#
# quite
#
# similar words:
# word:  muse   with similarity:  0.58699465
# word:  indecisive   with similarity:  0.57229245
# word:  disorganised   with similarity:  0.565783
# Dissimilar: exhibitions -0.33136702
#
# ##end
#
# similar words:
# word:  subconscio   with similarity:  0.15720958
# word:  ##ve   with similarity:  0.15185425
# word:  ##efuddl   with similarity:  0.14087233
# Dissimilar: ##sag -0.14823033
#
# weekend
#
# similar words:
# word:  ll   with similarity:  0.7502737
# word:  devote   with similarity:  0.73131835
# word:  repeating   with similarity:  0.6898844
# Dissimilar: eulalias -0.402131
#
# legend
#
# similar words:
# word:  remaining   with similarity:  0.8171421
# word:  cartwheel   with similarity:  0.78675365
# word:  title   with similarity:  0.7672502
# Dissimilar: personality -0.46951807
#
# offend
#
# similar words:
# word:  cock   with similarity:  0.1640517
# word:  ##tforwarding   with similarity:  0.14933088
# word:  ##rvativ   with similarity:  0.13223271
# Dissimilar: ##autiful -0.15554062
#
# tend
#
# similar words:
# word:  resigned   with similarity:  0.86354244
# word:  vow   with similarity:  0.8386437
# word:  percieve   with similarity:  0.8270354
# Dissimilar: east -0.5372721
#
# send
#
# similar words:
# word:  assistant   with similarity:  0.7568204
# word:  university   with similarity:  0.7232206
# word:  passage   with similarity:  0.71576035
# Dissimilar: nor -0.3216784
#
# ##nde
#
# similar words:
# word:  ##rabb   with similarity:  0.16418296
# word:  spok   with similarity:  0.16105826
# word:  snail   with similarity:  0.14990708
# Dissimilar: wp -0.18643561
#
# ##ndee
#
# similar words:
# word:  humanit   with similarity:  0.17131948
# word:  tri   with similarity:  0.1419406
# word:  ##egardl   with similarity:  0.13611308
# Dissimilar: offic -0.15308228
#
# ##ndeed
#
# similar words:
# word:  ##thwh   with similarity:  0.13858101
# word:  ##noon   with similarity:  0.13322842
# word:  ##actical   with similarity:  0.13311088
# Dissimilar: univers -0.18619786
#
# offende
#
# similar words:
# word:  ##troying   with similarity:  0.16574807
# word:  ##du   with similarity:  0.15468131
# word:  evolve   with similarity:  0.15077952
# Dissimilar: ##esemblanc -0.18414167
#
# offended
#
# similar words:
# word:  subaru   with similarity:  0.83914137
# word:  spiteful   with similarity:  0.8306123
# word:  submissive   with similarity:  0.79655695
# Dissimilar: ntoward -0.6300386
#
# come
#
# similar words:
# word:  cop   with similarity:  0.6305716
# word:  holyhead   with similarity:  0.5924565
# word:  sleep   with similarity:  0.5654043
# Dissimilar: east -0.42261493
#
# comes
#
# similar words:
# word:  flee   with similarity:  0.698348
# word:  event   with similarity:  0.6589812
# word:  club   with similarity:  0.63028824
# Dissimilar: ntoward -0.5645428
#
# ##ead
#
# similar words:
# word:  ##rhap   with similarity:  0.15047124
# word:  ##lon   with similarity:  0.14614172
# word:  ##start   with similarity:  0.13697116
# Dissimilar: ##urtur -0.15021482
#
# read
#
# similar words:
# word:  table   with similarity:  0.67029566
# word:  stepped   with similarity:  0.66823554
# word:  emily   with similarity:  0.6502669
# Dissimilar: east -0.46834767
#
# dread
#
# similar words:
# word:  soda   with similarity:  0.8958268
# word:  mountain   with similarity:  0.8804213
# word:  blessing   with similarity:  0.87100935
# Dissimilar: islam -0.66015387
#
# ##read
#
# similar words:
# word:  ##hibi   with similarity:  0.15367067
# word:  ##nuscul   with similarity:  0.13888556
# word:  impressiv   with similarity:  0.13779859
# Dissimilar: ##narticula -0.14272939
#
# tad
#
# similar words:
# word:  failure   with similarity:  0.7664496
# word:  blessing   with similarity:  0.7483221
# word:  ghost   with similarity:  0.74680173
# Dissimilar: personality -0.45842648
#
# rt
#
# similar words:
# word:  purchase   with similarity:  0.17674997
# word:  accomplishing   with similarity:  0.15694705
# word:  ##evot   with similarity:  0.15635788
# Dissimilar: artisa -0.14702466
#
# ##eread
#
# similar words:
# word:  ##oisturizing   with similarity:  0.16494718
# word:  yardage   with similarity:  0.14937557
# word:  ##evamp   with similarity:  0.14898285
# Dissimilar: ##ronto -0.14541112
#
# reread
#
# similar words:
# word:  turns   with similarity:  0.865234
# word:  housekeep   with similarity:  0.80745167
# word:  cringe   with similarity:  0.8043697
# Dissimilar: personality -0.59658086
#
# rte
#
# similar words:
# word:  emoticons   with similarity:  0.78215736
# word:  img   with similarity:  0.5680178
# word:  mrdanbaird   with similarity:  0.5387637
# Dissimilar: gotta -0.19873083
#
# shocke
#
# similar words:
# word:  happier   with similarity:  0.13833365
# word:  ##ndorphi   with similarity:  0.13811256
# word:  lattic   with similarity:  0.13593873
# Dissimilar: ##coho -0.17948085
#
# shocked
#
# similar words:
# word:  offended   with similarity:  0.6977637
# word:  irritated   with similarity:  0.6830448
# word:  surprised   with similarity:  0.6818265
# Dissimilar: ntoward -0.52359915
#
# hope
#
# similar words:
# word:  thought   with similarity:  0.7927776
# word:  wish   with similarity:  0.76290864
# word:  decided   with similarity:  0.74935544
# Dissimilar: birding -0.503394
#
# hopel
#
# similar words:
# word:  ##elligence   with similarity:  0.16379093
# word:  ##arrow   with similarity:  0.14144048
# word:  ##cessity   with similarity:  0.13834038
# Dissimilar: craisins -0.14274779
#
# hopes
#
# similar words:
# word:  succeed   with similarity:  0.67478263
# word:  abound   with similarity:  0.6624858
# word:  accordance   with similarity:  0.65441334
# Dissimilar: east -0.3768621
#
# hopele
#
# similar words:
# word:  ##wa   with similarity:  0.15331371
# word:  individually   with similarity:  0.15179418
# word:  surprise   with similarity:  0.15169837
# Dissimilar: until -0.18849745
#
# hopeless
#
# similar words:
# word:  uber   with similarity:  0.84156084
# word:  stare   with similarity:  0.83795077
# word:  admiration   with similarity:  0.8377331
# Dissimilar: personality -0.5654409
#
# she
#
# similar words:
# word:  he   with similarity:  0.5873076
# word:  biochemistry   with similarity:  0.49817127
# word:  arun   with similarity:  0.47170174
# Dissimilar: imprinted -0.30829427
#
# shr
#
# similar words:
# word:  ##erat   with similarity:  0.16025525
# word:  experiencing   with similarity:  0.14499255
# word:  ##iction   with similarity:  0.14181519
# Dissimilar: promotio -0.17133427
#
# shes
#
# similar words:
# word:  hes   with similarity:  0.658298
# word:  disadvantaged   with similarity:  0.6474829
# word:  homey   with similarity:  0.63147104
# Dissimilar: ntoward -0.43260688
#
# shre
#
# similar words:
# word:  subpar   with similarity:  0.15381926
# word:  despond   with similarity:  0.15135638
# word:  drove   with similarity:  0.14915772
# Dissimilar: ##ntrusion -0.16406986
#
# shred
#
# similar words:
# word:  exchange   with similarity:  0.57841015
# word:  tab   with similarity:  0.5726587
# word:  dlpt   with similarity:  0.5656891
# Dissimilar: halloween -0.41052508
#
# live
#
# similar words:
# word:  walk   with similarity:  0.7651869
# word:  stated   with similarity:  0.7479612
# word:  encounter   with similarity:  0.7425829
# Dissimilar: east -0.5472678
#
# lives
#
# similar words:
# word:  parenting   with similarity:  0.73688984
# word:  awhile   with similarity:  0.6218238
# word:  metal   with similarity:  0.6094786
# Dissimilar: east -0.4362477
#
# accepte
#
# similar words:
# word:  spinn   with similarity:  0.13862032
# word:  ##edia   with similarity:  0.13700424
# word:  austra   with similarity:  0.13465683
# Dissimilar: designer -0.16307141
#
# accepted
#
# similar words:
# word:  burdened   with similarity:  0.7859721
# word:  poo   with similarity:  0.7511035
# word:  honoured   with similarity:  0.73971844
# Dissimilar: ntoward -0.5140927
#
# ##ens
#
# similar words:
# word:  exa   with similarity:  0.16378893
# word:  ##lignc   with similarity:  0.1416524
# word:  parties   with similarity:  0.1326065
# Dissimilar: rach -0.16801488
#
# jens
#
# similar words:
# word:  retirement   with similarity:  0.6152688
# word:  consumers   with similarity:  0.51767147
# word:  lovebox   with similarity:  0.5049273
# Dissimilar: please -0.25439957
#
# sens
#
# similar words:
# word:  qualit   with similarity:  0.15043814
# word:  twa   with similarity:  0.14701368
# word:  vom   with similarity:  0.14584923
# Dissimilar: unsuc -0.17991853
#
# listens
#
# similar words:
# word:  percieve   with similarity:  0.81394184
# word:  forth   with similarity:  0.75852
# word:  faithfulness   with similarity:  0.74074924
# Dissimilar: east -0.5283382
#
# tons
#
# similar words:
# word:  jason   with similarity:  0.78705084
# word:  disapprove   with similarity:  0.7848828
# word:  blankets   with similarity:  0.7808882
# Dissimilar: ntoward -0.49532127
#
# sense
#
# similar words:
# word:  combined   with similarity:  0.6704916
# word:  portrayal   with similarity:  0.6532935
# word:  morsel   with similarity:  0.6366308
# Dissimilar: eulalias -0.29983842
#
# ##er
#
# similar words:
# word:  lifting   with similarity:  0.5051962
# word:  text   with similarity:  0.47515917
# word:  bull   with similarity:  0.47300583
# Dissimilar: tourists -0.33280146
#
# matter
#
# similar words:
# word:  acceptance   with similarity:  0.72734505
# word:  possess   with similarity:  0.6498532
# word:  directly   with similarity:  0.64617074
# Dissimilar: instructions -0.45204824
#
# flower
#
# similar words:
# word:  crystal   with similarity:  0.60022926
# word:  courage   with similarity:  0.58843476
# word:  sometime   with similarity:  0.56222034
# Dissimilar: hugely -0.42081034
#
# tender
#
# similar words:
# word:  groggy   with similarity:  0.7157192
# word:  suspicious   with similarity:  0.66985196
# word:  vulnerable   with similarity:  0.66398007
# Dissimilar: unconsciously -0.4522922
#
# paper
#
# similar words:
# word:  blink   with similarity:  0.83847374
# word:  midst   with similarity:  0.79572874
# word:  increasingly   with similarity:  0.78380203
# Dissimilar: east -0.52337563
#
# bother
#
# similar words:
# word:  stress   with similarity:  0.81307894
# word:  threaten   with similarity:  0.7896715
# word:  fuck   with similarity:  0.77714205
# Dissimilar: easygoing -0.48586553
#
# younger
#
# similar words:
# word:  truck   with similarity:  0.7506193
# word:  among   with similarity:  0.7383572
# word:  ankle   with similarity:  0.73224473
# Dissimilar: east -0.455256
#
# slower
#
# similar words:
# word:  weak   with similarity:  0.6640972
# word:  accepting   with similarity:  0.64737976
# word:  expressing   with similarity:  0.6115725
# Dissimilar: unconsciously -0.47675282
#
# employer
#
# similar words:
# word:  jasons   with similarity:  0.8096764
# word:  spain   with similarity:  0.55300677
# word:  speaking   with similarity:  0.533538
# Dissimilar: understad -0.29307008
#
# sober
#
# similar words:
# word:  idol   with similarity:  0.9228918
# word:  stay   with similarity:  0.7121384
# word:  aid   with similarity:  0.70219576
# Dissimilar: ntoward -0.5245118
#
# leader
#
# similar words:
# word:  elder   with similarity:  0.6877432
# word:  twin   with similarity:  0.6583734
# word:  district   with similarity:  0.61059254
# Dissimilar: goddamn -0.3865746
#
# teacher
#
# similar words:
# word:  bag   with similarity:  0.8836278
# word:  climb   with similarity:  0.86997163
# word:  ward   with similarity:  0.8513658
# Dissimilar: ntoward -0.56644994
#
# follower
#
# similar words:
# word:  dlpt   with similarity:  0.7599976
# word:  ending   with similarity:  0.75368637
# word:  accidentally   with similarity:  0.74525404
# Dissimilar: ntoward -0.403996
#
# shower
#
# similar words:
# word:  wuss   with similarity:  0.7433656
# word:  soda   with similarity:  0.74017906
# word:  sip   with similarity:  0.71497536
# Dissimilar: islam -0.47687155
#
# designer
#
# similar words:
# word:  hollow   with similarity:  0.64927447
# word:  goodwill   with similarity:  0.6482754
# word:  paused   with similarity:  0.6269456
# Dissimilar: sasha -0.43712178
#
# wilder
#
# similar words:
# word:  closet   with similarity:  0.6335741
# word:  sniiiiifff   with similarity:  0.583503
# word:  joel   with similarity:  0.58301306
# Dissimilar: losing -0.29091448
#
# number
#
# similar words:
# word:  diary   with similarity:  0.73583645
# word:  stack   with similarity:  0.7030133
# word:  recollection   with similarity:  0.68085235
# Dissimilar: hugely -0.44016933
#
# greater
#
# similar words:
# word:  transcendent   with similarity:  0.58668244
# word:  tychelle   with similarity:  0.438011
# word:  medication   with similarity:  0.4335712
# Dissimilar: [PAD] -0.31619787
#
# per
#
# similar words:
# word:  cara   with similarity:  0.713047
# word:  lucas   with similarity:  0.6836015
# word:  grows   with similarity:  0.6338953
# Dissimilar: standing -0.29106766
#
# prayer
#
# similar words:
# word:  saddle   with similarity:  0.8142991
# word:  coppers   with similarity:  0.808709
# word:  disapprove   with similarity:  0.80818176
# Dissimilar: personality -0.49612004
